# %%
import numpy as np
import pandas as pd

csv_data_path = 'https://raw.githubusercontent.com/turingplanet/pandas-intro/main/public-datasets/small_survey_results.csv'
survey_df = pd.read_csv(csv_data_path)

# %%
survey_df
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0         20900  I am a developer by profession      Yes   NaN         10
# 1         28235  I am a developer by profession       No  45.0         10
# 2         26082  I am a developer by profession      Yes  23.0         14
# 3         19890  I am a developer by profession      Yes  61.0         21
# 4         16393  I am a developer by profession      Yes  25.0         15
# ..          ...                             ...      ...   ...        ...
# 995       51360  I am a developer by profession      Yes  26.0         13
# 996       16771  I am a developer by profession      Yes   NaN         11
# 997       38831  I am a developer by profession      Yes   NaN        NaN
# 998        7093  I am a developer by profession      Yes   NaN        NaN
# 999       51843  I am a developer by profession      Yes  29.0         20
#
#     CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# 0    Monthly     8000.0        53040.0       Bulgaria         Bulgarian lev
# 1    Monthly   670000.0       867480.0         Norway       Norwegian krone
# 2     Yearly    65000.0        65000.0  United States  United States dollar
# 3        NaN        NaN            NaN         Canada       Canadian dollar
# 4     Weekly        NaN            NaN        Uruguay        Uruguayan peso
# ..       ...        ...            ...            ...                   ...
# 995  Monthly    16000.0        12312.0          Egypt        Egyptian pound
# 996      NaN        NaN            NaN  United States  United States dollar
# 997      NaN        NaN            NaN    Netherlands                   NaN
# 998      NaN        NaN            NaN      Indonesia     Indonesian rupiah
# 999  Monthly    90000.0        10680.0          Kenya       Kenyan shilling
#
#      ...                  SurveyEase           SurveyLength Trans  \
# 0    ...                         NaN                    NaN    No
# 1    ...                        Easy  Appropriate in length    No
# 2    ...                        Easy  Appropriate in length    No
# 3    ...                        Easy  Appropriate in length   NaN
# 4    ...                        Easy  Appropriate in length    No
# ..   ...                         ...                    ...   ...
# 995  ...  Neither easy nor difficult  Appropriate in length    No
# 996  ...                         NaN                    NaN   NaN
# 997  ...                         NaN                    NaN   NaN
# 998  ...                         NaN                    NaN   NaN
# 999  ...                        Easy  Appropriate in length    No
#
#                                         UndergradMajor  \
# 0    Computer science, computer engineering, or sof...
# 1    Computer science, computer engineering, or sof...
# 2    Computer science, computer engineering, or sof...
# 3    Another engineering discipline (such as civil,...
# 4    Another engineering discipline (such as civil,...
# ..                                                 ...
# 995  Another engineering discipline (such as civil,...
# 996  Another engineering discipline (such as civil,...
# 997                                                NaN
# 998                                                NaN
# 999  Information systems, information technology, o...
#
#                 WebframeDesireNextYear  \
# 0                                  NaN
# 1                                  NaN
# 2                ASP.NET Core;React.js
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 995                   Express;React.js
# 996             Angular;Express;Spring
# 997                                NaN
# 998                                NaN
# 999  Angular;Angular.js;jQuery;Laravel
#
#                               WebframeWorkedWith  \
# 0                                            NaN
# 1                                            NaN
# 2    ASP.NET Core;jQuery;Laravel;React.js;Vue.js
# 3                                            NaN
# 4                                          Flask
# ..                                           ...
# 995                  Angular;Angular.js;React.js
# 996                       Angular;Express;Spring
# 997                                          NaN
# 998                                          NaN
# 999            Angular;Angular.js;jQuery;Laravel
#
#                                 WelcomeChange WorkWeekHrs YearsCode  \
# 0     Just as welcome now as I felt last year        45.0        23
# 1     Just as welcome now as I felt last year        37.0        35
# 2       A lot less welcome now than last year        45.0         9
# 3    Somewhat less welcome now than last year        40.0        39
# 4     Just as welcome now as I felt last year        40.0        10
# ..                                        ...         ...       ...
# 995   Just as welcome now as I felt last year        40.0        10
# 996   Just as welcome now as I felt last year        50.0        41
# 997                                       NaN         NaN       NaN
# 998                                       NaN         NaN       NaN
# 999   Just as welcome now as I felt last year         8.0         8
#
#     YearsCodePro
# 0             15
# 1             22
# 2              5
# 3             29
# 4              3
# ..           ...
# 995            3
# 996           24
# 997          NaN
# 998          NaN
# 999            5
#
# [1000 rows x 61 columns]

# %%
survey_df.set_index('Respondent', inplace = True) # 将 Respondent 设为 index id

# %%
survey_df.sort_values(by = 'Age', ascending = False) # 按照年龄从大到小进行排序（最年长的竟然是67岁！）
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 36576                          I am a developer by profession      Yes  67.0
# 56924       I used to be a developer by profession, but no...      Yes  63.0
# 3251                              I code primarily as a hobby      Yes  62.0
# 19890                          I am a developer by profession      Yes  61.0
# 57451                          I am a developer by profession       No  61.0
# ...                                                       ...      ...   ...
# 275                            I am a developer by profession       No   NaN
# 63802                          I am a developer by profession      Yes   NaN
# 16771                          I am a developer by profession      Yes   NaN
# 38831                          I am a developer by profession      Yes   NaN
# 7093                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 36576              18  Monthly    35000.0         6600.0  Russian Federation
# 56924              24      NaN        NaN            NaN              Sweden
# 3251               18      NaN        NaN            NaN             Finland
# 19890              21      NaN        NaN            NaN              Canada
# 57451              19   Yearly   600000.0        64737.0              Norway
# ...               ...      ...        ...            ...                 ...
# 275                18      NaN        NaN            NaN               Nepal
# 63802              20  Monthly        NaN            NaN               India
# 16771              11      NaN        NaN            NaN       United States
# 38831             NaN      NaN        NaN            NaN         Netherlands
# 7093              NaN      NaN        NaN            NaN           Indonesia
#
#                     CurrencyDesc CurrencySymbol  ...  \
# Respondent                                       ...
# 36576              Russian ruble            RUB  ...
# 56924                        NaN            NaN  ...
# 3251                         NaN            NaN  ...
# 19890            Canadian dollar            CAD  ...
# 57451            Norwegian krone            NOK  ...
# ...                          ...            ...  ...
# 275                          NaN            NaN  ...
# 63802               Indian rupee            INR  ...
# 16771       United States dollar            USD  ...
# 38831                        NaN            NaN  ...
# 7093           Indonesian rupiah            IDR  ...
#
#                             SurveyEase           SurveyLength Trans  \
# Respondent
# 36576       Neither easy nor difficult  Appropriate in length    No
# 56924                             Easy  Appropriate in length    No
# 3251                              Easy  Appropriate in length    No
# 19890                             Easy  Appropriate in length   NaN
# 57451                             Easy  Appropriate in length    No
# ...                                ...                    ...   ...
# 275                               Easy  Appropriate in length    No
# 63802                              NaN                    NaN   NaN
# 16771                              NaN                    NaN   NaN
# 38831                              NaN                    NaN   NaN
# 7093                               NaN                    NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 36576       Another engineering discipline (such as civil,...
# 56924       A social science (such as anthropology, psycho...
# 3251        A business discipline (such as accounting, fin...
# 19890       Another engineering discipline (such as civil,...
# 57451                                                     NaN
# ...                                                       ...
# 275         Computer science, computer engineering, or sof...
# 63802       Computer science, computer engineering, or sof...
# 16771       Another engineering discipline (such as civil,...
# 38831                                                     NaN
# 7093                                                      NaN
#
#                       WebframeDesireNextYear      WebframeWorkedWith  \
# Respondent
# 36576                                    NaN                     NaN
# 56924                                    NaN         jQuery;React.js
# 3251                                   Flask                   Flask
# 19890                                    NaN                     NaN
# 57451                                 Vue.js                React.js
# ...                                      ...                     ...
# 275         Angular.js;Express;Spring;Vue.js           Spring;Vue.js
# 63802                                    NaN                     NaN
# 16771                 Angular;Express;Spring  Angular;Express;Spring
# 38831                                    NaN                     NaN
# 7093                                     NaN                     NaN
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 36576       Somewhat more welcome now than last year        40.0        50
# 56924        Just as welcome now as I felt last year         NaN        35
# 3251         Just as welcome now as I felt last year         NaN         3
# 19890       Somewhat less welcome now than last year        40.0        39
# 57451        Just as welcome now as I felt last year        38.0        42
# ...                                              ...         ...       ...
# 275         Somewhat more welcome now than last year         NaN         6
# 63802                                            NaN         NaN         3
# 16771        Just as welcome now as I felt last year        50.0        41
# 38831                                            NaN         NaN       NaN
# 7093                                             NaN         NaN       NaN
#
#            YearsCodePro
# Respondent
# 36576                45
# 56924               NaN
# 3251                NaN
# 19890                29
# 57451                35
# ...                 ...
# 275                 NaN
# 63802                 2
# 16771                24
# 38831               NaN
# 7093                NaN
#
# [1000 rows x 60 columns]

# %%
survey_df.sort_values(by = ['Age', 'YearsCode'], ascending = False) # 使用多列进行排序，先按照Age进行排序，再按照YearsCode进行排序
survey_df.sort_values(by = ['Age', 'YearsCode'], ascending = [0, 1], inplace = True)

# %%
survey_df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 36576                          I am a developer by profession      Yes  67.0
# 56924       I used to be a developer by profession, but no...      Yes  63.0
# 3251                              I code primarily as a hobby      Yes  62.0
# 19890                          I am a developer by profession      Yes  61.0
# 57451                          I am a developer by profession       No  61.0
# ...                                                       ...      ...   ...
# 45154                          I am a developer by profession      Yes   NaN
# 59877                          I am a developer by profession      Yes   NaN
# 64744                          I am a developer by profession      Yes   NaN
# 38831                          I am a developer by profession      Yes   NaN
# 7093                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 36576              18  Monthly    35000.0         6600.0  Russian Federation
# 56924              24      NaN        NaN            NaN              Sweden
# 3251               18      NaN        NaN            NaN             Finland
# 19890              21      NaN        NaN            NaN              Canada
# 57451              19   Yearly   600000.0        64737.0              Norway
# ...               ...      ...        ...            ...                 ...
# 45154             NaN      NaN        NaN            NaN             Lebanon
# 59877             NaN      NaN        NaN            NaN         Philippines
# 64744             NaN      NaN        NaN            NaN          Costa Rica
# 38831             NaN      NaN        NaN            NaN         Netherlands
# 7093              NaN      NaN        NaN            NaN           Indonesia
#
#                  CurrencyDesc CurrencySymbol  ...                  SurveyEase  \
# Respondent                                    ...
# 36576           Russian ruble            RUB  ...  Neither easy nor difficult
# 56924                     NaN            NaN  ...                        Easy
# 3251                      NaN            NaN  ...                        Easy
# 19890         Canadian dollar            CAD  ...                        Easy
# 57451         Norwegian krone            NOK  ...                        Easy
# ...                       ...            ...  ...                         ...
# 45154                     NaN            NaN  ...                         NaN
# 59877                     NaN            NaN  ...                         NaN
# 64744                     NaN            NaN  ...                         NaN
# 38831                     NaN            NaN  ...                         NaN
# 7093        Indonesian rupiah            IDR  ...                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 36576       Appropriate in length    No
# 56924       Appropriate in length    No
# 3251        Appropriate in length    No
# 19890       Appropriate in length   NaN
# 57451       Appropriate in length    No
# ...                           ...   ...
# 45154                         NaN   NaN
# 59877                         NaN   NaN
# 64744                         NaN   NaN
# 38831                         NaN   NaN
# 7093                          NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 36576       Another engineering discipline (such as civil,...
# 56924       A social science (such as anthropology, psycho...
# 3251        A business discipline (such as accounting, fin...
# 19890       Another engineering discipline (such as civil,...
# 57451                                                     NaN
# ...                                                       ...
# 45154                                                     NaN
# 59877                                                     NaN
# 64744                                                     NaN
# 38831                                                     NaN
# 7093                                                      NaN
#
#            WebframeDesireNextYear WebframeWorkedWith  \
# Respondent
# 36576                         NaN                NaN
# 56924                         NaN    jQuery;React.js
# 3251                        Flask              Flask
# 19890                         NaN                NaN
# 57451                      Vue.js           React.js
# ...                           ...                ...
# 45154             Angular;Laravel           React.js
# 59877                         NaN           React.js
# 64744                         NaN                NaN
# 38831                         NaN                NaN
# 7093                          NaN                NaN
#
#                                        WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 36576       Somewhat more welcome now than last year        40.0        50
# 56924        Just as welcome now as I felt last year         NaN        35
# 3251         Just as welcome now as I felt last year         NaN         3
# 19890       Somewhat less welcome now than last year        40.0        39
# 57451        Just as welcome now as I felt last year        38.0        42
# ...                                              ...         ...       ...
# 45154                                            NaN         NaN       NaN
# 59877                                            NaN         NaN       NaN
# 64744                                            NaN         NaN       NaN
# 38831                                            NaN         NaN       NaN
# 7093                                             NaN         NaN       NaN
#
#            YearsCodePro
# Respondent
# 36576                45
# 56924               NaN
# 3251                NaN
# 19890                29
# 57451                35
# ...                 ...
# 45154               NaN
# 59877               NaN
# 64744               NaN
# 38831               NaN
# 7093                NaN
#
# [1000 rows x 60 columns]

# %%
survey_df['Age'].sort_values() # 将用户的年龄从小到大排序
# Out:
# Respondent
# 59748    13.0
# 11615    15.0
# 29215    15.0
# 23837    15.0
# 4656     15.0
#          ...
# 45154     NaN
# 59877     NaN
# 64744     NaN
# 38831     NaN
# 7093      NaN
# Name: Age, Length: 1000, dtype: float64

# %%
survey_df['ConvertedComp'].nlargest(10) # 前10名工资最高的用户工资信息
# Out:
# Respondent
# 29378    1000000.0
# 48807    1000000.0
# 18603     946944.0
# 5292      907572.0
# 28235     867480.0
# 19800     863316.0
# 47454     843168.0
# 21172     801720.0
# 59314     753936.0
# 26443     744000.0
# Name: ConvertedComp, dtype: float64

# %%
survey_df['ConvertedComp'].nsmallest(20) # 工资最低的前十名用户工资信息
# Out:
# Respondent
# 56562       0.0
# 50800    1164.0
# 35324    1512.0
# 60592    1644.0
# 9451     1944.0
# 34102    2064.0
# 63944    2340.0
# 6992     2520.0
# 62991    2556.0
# 48554    2844.0
# 28773    3324.0
# 56558    3564.0
# 9100     3672.0
# 58099    3684.0
# 753      3852.0
# 24115    3984.0
# 54771    4188.0
# 6897     4188.0
# 9331     4356.0
# 54864    4356.0
# Name: ConvertedComp, dtype: float64

# %%
richest_users = survey_df.nlargest(10, 'ConvertedComp') # 拿到工资最高的前10名用户数据

# %%
richest_users[['ConvertedComp', 'DevType', 'EdLevel']]
# Out:
#             ConvertedComp                                            DevType  \
# Respondent
# 29378           1000000.0  Data or business analyst;Data scientist or mac...
# 48807           1000000.0                                                NaN
# 18603            946944.0         Database administrator;Developer, back-end
# 5292             907572.0                                Developer, back-end
# 28235            867480.0                                  Developer, mobile
# 19800            863316.0           Developer, back-end;Developer, front-end
# 47454            843168.0  Developer, back-end;Developer, full-stack;Deve...
# 21172            801720.0  Developer, back-end;Developer, front-end;Devel...
# 59314            753936.0  Data scientist or machine learning specialist;...
# 26443            744000.0  Developer, back-end;Developer, desktop or ente...
#
#                                                       EdLevel
# Respondent
# 29378         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 48807         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18603            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5292        Some college/university study without earning ...
# 28235            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19800            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47454         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 21172            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59314            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 26443            Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
survey_df.nsmallest(10, 'ConvertedComp')[['ConvertedComp', 'DevType', 'EdLevel']] # 按低工资排序的前10名用户相关信息
# Out:
#             ConvertedComp                                            DevType  \
# Respondent
# 56562                 0.0  Developer, back-end;Developer, front-end;Devel...
# 50800              1164.0  Developer, back-end;Developer, desktop or ente...
# 35324              1512.0  Data or business analyst;Data scientist or mac...
# 60592              1644.0  Data or business analyst;Database administrato...
# 9451               1944.0  Developer, back-end;Developer, front-end;Devel...
# 34102              2064.0                                Developer, back-end
# 63944              2340.0                       Developer, back-end;Educator
# 6992               2520.0  Developer, back-end;Developer, front-end;Devel...
# 62991              2556.0  Academic researcher;Developer, desktop or ente...
# 48554              2844.0  Academic researcher;Designer;Developer, back-e...
#
#                                                     EdLevel
# Respondent
# 56562          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 50800          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35324       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 60592          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9451        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34102          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63944       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6992           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62991          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 48554          Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
for col_name, col_data in survey_df.items(): # 迭代列
    print(col_name) # 打印列名
    print(col_data) # 打印列上的数据
# Out:
# MainBranch
# Respondent
# 36576                       I am a developer by profession
# 56924    I used to be a developer by profession, but no...
# 3251                           I code primarily as a hobby
# 19890                       I am a developer by profession
# 57451                       I am a developer by profession
#                                ...
# 45154                       I am a developer by profession
# 59877                       I am a developer by profession
# 64744                       I am a developer by profession
# 38831                       I am a developer by profession
# 7093                        I am a developer by profession
# Name: MainBranch, Length: 1000, dtype: object
# Hobbyist
# Respondent
# 36576    Yes
# 56924    Yes
# 3251     Yes
# 19890    Yes
# 57451     No
#         ...
# 45154    Yes
# 59877    Yes
# 64744    Yes
# 38831    Yes
# 7093     Yes
# Name: Hobbyist, Length: 1000, dtype: object
# Age
# Respondent
# 36576    67.0
# 56924    63.0
# 3251     62.0
# 19890    61.0
# 57451    61.0
#          ...
# 45154     NaN
# 59877     NaN
# 64744     NaN
# 38831     NaN
# 7093      NaN
# Name: Age, Length: 1000, dtype: float64
# Age1stCode
# Respondent
# 36576     18
# 56924     24
# 3251      18
# 19890     21
# 57451     19
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     NaN
# Name: Age1stCode, Length: 1000, dtype: object
# CompFreq
# Respondent
# 36576    Monthly
# 56924        NaN
# 3251         NaN
# 19890        NaN
# 57451     Yearly
#           ...
# 45154        NaN
# 59877        NaN
# 64744        NaN
# 38831        NaN
# 7093         NaN
# Name: CompFreq, Length: 1000, dtype: object
# CompTotal
# Respondent
# 36576     35000.0
# 56924         NaN
# 3251          NaN
# 19890         NaN
# 57451    600000.0
#            ...
# 45154         NaN
# 59877         NaN
# 64744         NaN
# 38831         NaN
# 7093          NaN
# Name: CompTotal, Length: 1000, dtype: float64
# ConvertedComp
# Respondent
# 36576     6600.0
# 56924        NaN
# 3251         NaN
# 19890        NaN
# 57451    64737.0
#           ...
# 45154        NaN
# 59877        NaN
# 64744        NaN
# 38831        NaN
# 7093         NaN
# Name: ConvertedComp, Length: 1000, dtype: float64
# Country
# Respondent
# 36576    Russian Federation
# 56924                Sweden
# 3251                Finland
# 19890                Canada
# 57451                Norway
#                 ...
# 45154               Lebanon
# 59877           Philippines
# 64744            Costa Rica
# 38831           Netherlands
# 7093              Indonesia
# Name: Country, Length: 1000, dtype: object
# CurrencyDesc
# Respondent
# 36576        Russian ruble
# 56924                  NaN
# 3251                   NaN
# 19890      Canadian dollar
# 57451      Norwegian krone
#                ...
# 45154                  NaN
# 59877                  NaN
# 64744                  NaN
# 38831                  NaN
# 7093     Indonesian rupiah
# Name: CurrencyDesc, Length: 1000, dtype: object
# CurrencySymbol
# Respondent
# 36576    RUB
# 56924    NaN
# 3251     NaN
# 19890    CAD
# 57451    NOK
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     IDR
# Name: CurrencySymbol, Length: 1000, dtype: object
# DatabaseDesireNextYear
# Respondent
# 36576                                          SQLite
# 56924                                      PostgreSQL
# 3251     Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 19890                                             NaN
# 57451                                        Firebase
#                              ...
# 45154                                         MongoDB
# 59877                                             NaN
# 64744                                             NaN
# 38831                                             NaN
# 7093                                              NaN
# Name: DatabaseDesireNextYear, Length: 1000, dtype: object
# DatabaseWorkedWith
# Respondent
# 36576                                               SQLite
# 56924                          MariaDB;MySQL;Oracle;SQLite
# 3251          Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 19890                                 Microsoft SQL Server
# 57451                Microsoft SQL Server;MySQL;PostgreSQL
#                                ...
# 45154    Firebase;MariaDB;Microsoft SQL Server;MySQL;SQ...
# 59877                          Firebase;MongoDB;PostgreSQL
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: DatabaseWorkedWith, Length: 1000, dtype: object
# DevType
# Respondent
# 36576    Developer, back-end;Developer, desktop or ente...
# 56924                                                  NaN
# 3251                                                   NaN
# 19890    Designer;Developer, desktop or enterprise appl...
# 57451                 Developer, front-end;Product manager
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: DevType, Length: 1000, dtype: object
# EdLevel
# Respondent
# 36576           Other doctoral degree (Ph.D., Ed.D., etc.)
# 56924         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3251       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 19890                  Associate degree (A.A., A.S., etc.)
# 57451    Some college/university study without earning ...
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: EdLevel, Length: 1000, dtype: object
# Employment
# Respondent
# 36576    Employed full-time
# 56924               Retired
# 3251                Retired
# 19890    Employed full-time
# 57451    Employed full-time
#                 ...
# 45154    Employed part-time
# 59877    Employed full-time
# 64744    Employed full-time
# 38831    Employed full-time
# 7093     Employed full-time
# Name: Employment, Length: 1000, dtype: object
# Ethnicity
# Respondent
# 36576    White or of European descent
# 56924    White or of European descent
# 3251     White or of European descent
# 19890                             NaN
# 57451    White or of European descent
#                      ...
# 45154                             NaN
# 59877                             NaN
# 64744                             NaN
# 38831                             NaN
# 7093                              NaN
# Name: Ethnicity, Length: 1000, dtype: object
# Gender
# Respondent
# 36576    Man
# 56924    Man
# 3251     Man
# 19890    NaN
# 57451    Man
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     NaN
# Name: Gender, Length: 1000, dtype: object
# JobFactors
# Respondent
# 36576    Industry that I’d be working in;Languages, fra...
# 56924                                                  NaN
# 3251                                                   NaN
# 19890    Languages, frameworks, and other technologies ...
# 57451    Flex time or a flexible schedule;Languages, fr...
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: JobFactors, Length: 1000, dtype: object
# JobSat
# Respondent
# 36576    Slightly satisfied
# 56924                   NaN
# 3251                    NaN
# 19890    Slightly satisfied
# 57451        Very satisfied
#                 ...
# 45154                   NaN
# 59877                   NaN
# 64744                   NaN
# 38831                   NaN
# 7093                    NaN
# Name: JobSat, Length: 1000, dtype: object
# JobSeek
# Respondent
# 36576    I’m not actively looking, but I am open to new...
# 56924                                                  NaN
# 3251                                                   NaN
# 19890    I’m not actively looking, but I am open to new...
# 57451         I am not interested in new job opportunities
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                       I am actively looking for a job
# Name: JobSeek, Length: 1000, dtype: object
# LanguageDesireNextYear
# Respondent
# 36576                                  C;Python;Rust
# 56924    Haskell;Java;JavaScript;Julia;Perl;Python;R
# 3251                           HTML/CSS;Python;R;SQL
# 19890                                      Go;Kotlin
# 57451                     Java;JavaScript;TypeScript
#                             ...
# 45154                                     TypeScript
# 59877                                            NaN
# 64744                                            NaN
# 38831                                            NaN
# 7093                                             NaN
# Name: LanguageDesireNextYear, Length: 1000, dtype: object
# LanguageWorkedWith
# Respondent
# 36576                                           C;Python;R
# 56924                               Java;Perl;Python;R;SQL
# 3251                                 HTML/CSS;Python;R;SQL
# 19890                                        C#;Python;VBA
# 57451                                      Java;JavaScript
#                                ...
# 45154    C#;Haskell;HTML/CSS;Java;JavaScript;PHP;Python...
# 59877                                    JavaScript;Python
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: LanguageWorkedWith, Length: 1000, dtype: object
# MiscTechDesireNextYear
# Respondent
# 36576                                  Pandas
# 56924         Keras;Node.js;Pandas;TensorFlow
# 3251     Apache Spark;Keras;Pandas;TensorFlow
# 19890                                     NaN
# 57451                         Flutter;Node.js
#                          ...
# 45154                                     NaN
# 59877                                     NaN
# 64744                                     NaN
# 38831                                     NaN
# 7093                                      NaN
# Name: MiscTechDesireNextYear, Length: 1000, dtype: object
# MiscTechWorkedWith
# Respondent
# 36576                                           Pandas
# 56924    Keras;Node.js;Pandas;TensorFlow;Torch/PyTorch
# 3251                                            Pandas
# 19890                                   .NET;.NET Core
# 57451                                          Node.js
#                              ...
# 45154                             Node.js;React Native
# 59877                  Node.js;React Native;TensorFlow
# 64744                                              NaN
# 38831                                              NaN
# 7093                                               NaN
# Name: MiscTechWorkedWith, Length: 1000, dtype: object
# NEWCollabToolsDesireNextYear
# Respondent
# 36576                                              Github
# 56924    Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 3251                                               Github
# 19890                                                 NaN
# 57451                                              Github
#                                ...
# 45154                                                 NaN
# 59877                                                 NaN
# 64744                                                 NaN
# 38831                                                 NaN
# 7093                                                  NaN
# Name: NEWCollabToolsDesireNextYear, Length: 1000, dtype: object
# NEWCollabToolsWorkedWith
# Respondent
# 36576                                               Github
# 56924    Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# 3251                                                   NaN
# 19890                                               Github
# 57451    Jira;Github;Slack;Microsoft Teams;Trello;Googl...
#                                ...
# 45154    Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 59877    Confluence;Jira;Github;Google Suite (Docs, Mee...
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: NEWCollabToolsWorkedWith, Length: 1000, dtype: object
# NEWDevOps
# Respondent
# 36576    Yes
# 56924    NaN
# 3251     NaN
# 19890     No
# 57451    Yes
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     NaN
# Name: NEWDevOps, Length: 1000, dtype: object
# NEWDevOpsImpt
# Respondent
# 36576     Somewhat important
# 56924                    NaN
# 3251                     NaN
# 19890     Somewhat important
# 57451    Extremely important
#                 ...
# 45154                    NaN
# 59877                    NaN
# 64744                    NaN
# 38831                    NaN
# 7093                     NaN
# Name: NEWDevOpsImpt, Length: 1000, dtype: object
# NEWEdImpt
# Respondent
# 36576      Fairly important
# 56924      Fairly important
# 3251         Very important
# 19890        Very important
# 57451    Somewhat important
#                 ...
# 45154                   NaN
# 59877                   NaN
# 64744                   NaN
# 38831                   NaN
# 7093                    NaN
# Name: NEWEdImpt, Length: 1000, dtype: object
# NEWJobHunt
# Respondent
# 36576                                  Better compensation
# 56924                                                  NaN
# 3251                                                   NaN
# 19890    Wanting to work with new technologies;Growth o...
# 57451                                                  NaN
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: NEWJobHunt, Length: 1000, dtype: object
# NEWJobHuntResearch
# Respondent
# 36576    Read company media, such as employee blogs or ...
# 56924                                                  NaN
# 3251                                                   NaN
# 19890    Read company media, such as employee blogs or ...
# 57451    Read company media, such as employee blogs or ...
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: NEWJobHuntResearch, Length: 1000, dtype: object
# NEWLearn
# Respondent
# 36576    Once every few years
# 56924             Once a year
# 3251     Once every few years
# 19890             Once a year
# 57451    Once every few years
#                  ...
# 45154        Every few months
# 59877        Every few months
# 64744                     NaN
# 38831                     NaN
# 7093                      NaN
# Name: NEWLearn, Length: 1000, dtype: object
# NEWOffTopic
# Respondent
# 36576          No
# 56924    Not sure
# 3251     Not sure
# 19890          No
# 57451    Not sure
#            ...
# 45154         NaN
# 59877         NaN
# 64744         NaN
# 38831         NaN
# 7093          NaN
# Name: NEWOffTopic, Length: 1000, dtype: object
# NEWOnboardGood
# Respondent
# 36576    Onboarding? What onboarding?
# 56924                             NaN
# 3251                              NaN
# 19890                             Yes
# 57451                              No
#                      ...
# 45154                             NaN
# 59877                             NaN
# 64744                             NaN
# 38831                             NaN
# 7093                              NaN
# Name: NEWOnboardGood, Length: 1000, dtype: object
# NEWOtherComms
# Respondent
# 36576    Yes
# 56924    Yes
# 3251     Yes
# 19890    Yes
# 57451    Yes
#         ...
# 45154    NaN
# 59877    Yes
# 64744    NaN
# 38831    NaN
# 7093     Yes
# Name: NEWOtherComms, Length: 1000, dtype: object
# NEWOvertime
# Respondent
# 36576    Occasionally: 1-2 days per quarter but less th...
# 56924                                                  NaN
# 3251                                                   NaN
# 19890    Sometimes: 1-2 days per month but less than we...
# 57451    Sometimes: 1-2 days per month but less than we...
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: NEWOvertime, Length: 1000, dtype: object
# NEWPurchaseResearch
# Respondent
# 36576                                                  NaN
# 56924    Start a free trial;Ask developers I know/work ...
# 3251                                                   NaN
# 19890    Start a free trial;Ask developers I know/work ...
# 57451    Start a free trial;Ask developers I know/work ...
#                                ...
# 45154                                                  NaN
# 59877    Start a free trial;Ask developers I know/work ...
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: NEWPurchaseResearch, Length: 1000, dtype: object
# NEWPurpleLink
# Respondent
# 36576        Annoyed
# 56924         Amused
# 3251          Amused
# 19890    Indifferent
# 57451    Indifferent
#             ...
# 45154            NaN
# 59877         Amused
# 64744            NaN
# 38831            NaN
# 7093             NaN
# Name: NEWPurpleLink, Length: 1000, dtype: object
# NEWSOSites
# Respondent
# 36576     Stack Overflow (public Q&A for anyone who codes)
# 56924    Stack Overflow (public Q&A for anyone who code...
# 3251      Stack Overflow (public Q&A for anyone who codes)
# 19890     Stack Overflow (public Q&A for anyone who codes)
# 57451     Stack Overflow (public Q&A for anyone who codes)
#                                ...
# 45154                                                  NaN
# 59877     Stack Overflow (public Q&A for anyone who codes)
# 64744                                                  NaN
# 38831                                                  NaN
# 7093     Stack Overflow (public Q&A for anyone who code...
# Name: NEWSOSites, Length: 1000, dtype: object
# NEWStuck
# Respondent
# 36576    Call a coworker or friend;Visit Stack Overflow...
# 56924    Meditate;Visit Stack Overflow;Go for a walk or...
# 3251                                  Visit Stack Overflow
# 19890    Go for a walk or other physical activity;Visit...
# 57451    Call a coworker or friend;Visit Stack Overflow...
#                                ...
# 45154                                                  NaN
# 59877    Watch help / tutorial videos;Do other work and...
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: NEWStuck, Length: 1000, dtype: object
# OpSys
# Respondent
# 36576    Linux-based
# 56924    Linux-based
# 3251         Windows
# 19890        Windows
# 57451        Windows
#             ...
# 45154        Windows
# 59877          MacOS
# 64744            NaN
# 38831            NaN
# 7093             NaN
# Name: OpSys, Length: 1000, dtype: object
# OrgSize
# Respondent
# 36576    1,000 to 4,999 employees
# 56924                         NaN
# 3251                          NaN
# 19890    5,000 to 9,999 employees
# 57451    1,000 to 4,999 employees
#                    ...
# 45154                         NaN
# 59877                         NaN
# 64744                         NaN
# 38831                         NaN
# 7093                          NaN
# Name: OrgSize, Length: 1000, dtype: object
# PlatformDesireNextYear
# Respondent
# 36576                                Linux;Raspberry Pi
# 56924               Android;Google Cloud Platform;Linux
# 3251     AWS;Google Cloud Platform;Heroku;Linux;Windows
# 19890                                               NaN
# 57451                                   Android;Windows
#                               ...
# 45154                                            Docker
# 59877                                               NaN
# 64744                                               NaN
# 38831                                               NaN
# 7093                                                NaN
# Name: PlatformDesireNextYear, Length: 1000, dtype: object
# PlatformWorkedWith
# Respondent
# 36576                                                Linux
# 56924                          Google Cloud Platform;Linux
# 3251                                               Windows
# 19890                                    Windows;WordPress
# 57451                                              Windows
#                                ...
# 45154    Android;Arduino;Google Cloud Platform;Windows;...
# 59877                                Google Cloud Platform
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: PlatformWorkedWith, Length: 1000, dtype: object
# PurchaseWhat
# Respondent
# 36576       I have little or no influence
# 56924                                 NaN
# 3251                                  NaN
# 19890               I have some influence
# 57451    I have a great deal of influence
#                        ...
# 45154       I have little or no influence
# 59877    I have a great deal of influence
# 64744                                 NaN
# 38831                                 NaN
# 7093                                  NaN
# Name: PurchaseWhat, Length: 1000, dtype: object
# Sexuality
# Respondent
# 36576    Straight / Heterosexual
# 56924    Straight / Heterosexual
# 3251     Straight / Heterosexual
# 19890                        NaN
# 57451    Straight / Heterosexual
#                   ...
# 45154                        NaN
# 59877                        NaN
# 64744                        NaN
# 38831                        NaN
# 7093                         NaN
# Name: Sexuality, Length: 1000, dtype: object
# SOAccount
# Respondent
# 36576                        Yes
# 56924                        Yes
# 3251                         Yes
# 19890                        Yes
# 57451    Not sure/can't remember
#                   ...
# 45154                        NaN
# 59877                        Yes
# 64744                        NaN
# 38831                        NaN
# 7093                         Yes
# Name: SOAccount, Length: 1000, dtype: object
# SOComm
# Respondent
# 36576      Yes, somewhat
# 56924    Yes, definitely
# 3251       Yes, somewhat
# 19890     No, not really
# 57451            Neutral
#               ...
# 45154                NaN
# 59877            Neutral
# 64744                NaN
# 38831                NaN
# 7093     Yes, definitely
# Name: SOComm, Length: 1000, dtype: object
# SOPartFreq
# Respondent
# 36576                                 A few times per week
# 56924                                 A few times per week
# 3251     I have never participated in Q&A on Stack Over...
# 19890                  Less than once per month or monthly
# 57451                                                  NaN
#                                ...
# 45154                                                  NaN
# 59877    I have never participated in Q&A on Stack Over...
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                Multiple times per day
# Name: SOPartFreq, Length: 1000, dtype: object
# SOVisitFreq
# Respondent
# 36576                   A few times per week
# 56924                 Multiple times per day
# 3251                  Multiple times per day
# 19890        A few times per month or weekly
# 57451        A few times per month or weekly
#                         ...
# 45154                                    NaN
# 59877    Less than once per month or monthly
# 64744                                    NaN
# 38831                                    NaN
# 7093                  Multiple times per day
# Name: SOVisitFreq, Length: 1000, dtype: object
# SurveyEase
# Respondent
# 36576    Neither easy nor difficult
# 56924                          Easy
# 3251                           Easy
# 19890                          Easy
# 57451                          Easy
#                     ...
# 45154                           NaN
# 59877                           NaN
# 64744                           NaN
# 38831                           NaN
# 7093                            NaN
# Name: SurveyEase, Length: 1000, dtype: object
# SurveyLength
# Respondent
# 36576    Appropriate in length
# 56924    Appropriate in length
# 3251     Appropriate in length
# 19890    Appropriate in length
# 57451    Appropriate in length
#                  ...
# 45154                      NaN
# 59877                      NaN
# 64744                      NaN
# 38831                      NaN
# 7093                       NaN
# Name: SurveyLength, Length: 1000, dtype: object
# Trans
# Respondent
# 36576     No
# 56924     No
# 3251      No
# 19890    NaN
# 57451     No
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     NaN
# Name: Trans, Length: 1000, dtype: object
# UndergradMajor
# Respondent
# 36576    Another engineering discipline (such as civil,...
# 56924    A social science (such as anthropology, psycho...
# 3251     A business discipline (such as accounting, fin...
# 19890    Another engineering discipline (such as civil,...
# 57451                                                  NaN
#                                ...
# 45154                                                  NaN
# 59877                                                  NaN
# 64744                                                  NaN
# 38831                                                  NaN
# 7093                                                   NaN
# Name: UndergradMajor, Length: 1000, dtype: object
# WebframeDesireNextYear
# Respondent
# 36576                NaN
# 56924                NaN
# 3251               Flask
# 19890                NaN
# 57451             Vue.js
#               ...
# 45154    Angular;Laravel
# 59877                NaN
# 64744                NaN
# 38831                NaN
# 7093                 NaN
# Name: WebframeDesireNextYear, Length: 1000, dtype: object
# WebframeWorkedWith
# Respondent
# 36576                NaN
# 56924    jQuery;React.js
# 3251               Flask
# 19890                NaN
# 57451           React.js
#               ...
# 45154           React.js
# 59877           React.js
# 64744                NaN
# 38831                NaN
# 7093                 NaN
# Name: WebframeWorkedWith, Length: 1000, dtype: object
# WelcomeChange
# Respondent
# 36576    Somewhat more welcome now than last year
# 56924     Just as welcome now as I felt last year
# 3251      Just as welcome now as I felt last year
# 19890    Somewhat less welcome now than last year
# 57451     Just as welcome now as I felt last year
#                            ...
# 45154                                         NaN
# 59877                                         NaN
# 64744                                         NaN
# 38831                                         NaN
# 7093                                          NaN
# Name: WelcomeChange, Length: 1000, dtype: object
# WorkWeekHrs
# Respondent
# 36576    40.0
# 56924     NaN
# 3251      NaN
# 19890    40.0
# 57451    38.0
#          ...
# 45154     NaN
# 59877     NaN
# 64744     NaN
# 38831     NaN
# 7093      NaN
# Name: WorkWeekHrs, Length: 1000, dtype: float64
# YearsCode
# Respondent
# 36576     50
# 56924     35
# 3251       3
# 19890     39
# 57451     42
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     NaN
# Name: YearsCode, Length: 1000, dtype: object
# YearsCodePro
# Respondent
# 36576     45
# 56924    NaN
# 3251     NaN
# 19890     29
# 57451     35
#         ...
# 45154    NaN
# 59877    NaN
# 64744    NaN
# 38831    NaN
# 7093     NaN
# Name: YearsCodePro, Length: 1000, dtype: object

# %%
for row_index, row_info in survey_df.iterrows(): # 迭代行
    print(row_index) # 打印 index
    print(row_info) # 打印单行的所有列信息
# Out:
# 36576
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                            67
# Age1stCode                                                                     18
# CompFreq                                                                  Monthly
# CompTotal                                                                   35000
# ConvertedComp                                                                6600
# Country                                                        Russian Federation
# CurrencyDesc                                                        Russian ruble
# CurrencySymbol                                                                RUB
# DatabaseDesireNextYear                                                     SQLite
# DatabaseWorkedWith                                                         SQLite
# DevType                         Developer, back-end;Developer, desktop or ente...
# EdLevel                                Other doctoral degree (Ph.D., Ed.D., etc.)
# Employment                                                     Employed full-time
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Industry that I’d be working in;Languages, fra...
# JobSat                                                         Slightly satisfied
# JobSeek                         I’m not actively looking, but I am open to new...
# LanguageDesireNextYear                                              C;Python;Rust
# LanguageWorkedWith                                                     C;Python;R
# MiscTechDesireNextYear                                                     Pandas
# MiscTechWorkedWith                                                         Pandas
# NEWCollabToolsDesireNextYear                                               Github
# NEWCollabToolsWorkedWith                                                   Github
# NEWDevOps                                                                     Yes
# NEWDevOpsImpt                                                  Somewhat important
# NEWEdImpt                                                        Fairly important
# NEWJobHunt                                                    Better compensation
# NEWJobHuntResearch              Read company media, such as employee blogs or ...
# NEWLearn                                                     Once every few years
# NEWOffTopic                                                                    No
# NEWOnboardGood                                       Onboarding? What onboarding?
# NEWOtherComms                                                                 Yes
# NEWOvertime                     Occasionally: 1-2 days per quarter but less th...
# NEWPurchaseResearch                                                           NaN
# NEWPurpleLink                                                             Annoyed
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                 Linux-based
# OrgSize                                                  1,000 to 4,999 employees
# PlatformDesireNextYear                                         Linux;Raspberry Pi
# PlatformWorkedWith                                                          Linux
# PurchaseWhat                                        I have little or no influence
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                              Yes, somewhat
# SOPartFreq                                                   A few times per week
# SOVisitFreq                                                  A few times per week
# SurveyEase                                             Neither easy nor difficult
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                        NaN
# WebframeWorkedWith                                                            NaN
# WelcomeChange                            Somewhat more welcome now than last year
# WorkWeekHrs                                                                    40
# YearsCode                                                                      50
# YearsCodePro                                                                   45
# Name: 36576, dtype: object
# 56924
# MainBranch                      I used to be a developer by profession, but no...
# Hobbyist                                                                      Yes
# Age                                                                            63
# Age1stCode                                                                     24
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                    Sweden
# CurrencyDesc                                                                  NaN
# CurrencySymbol                                                                NaN
# DatabaseDesireNextYear                                                 PostgreSQL
# DatabaseWorkedWith                                    MariaDB;MySQL;Oracle;SQLite
# DevType                                                                       NaN
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                                Retired
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                                                                    NaN
# JobSat                                                                        NaN
# JobSeek                                                                       NaN
# LanguageDesireNextYear                Haskell;Java;JavaScript;Julia;Perl;Python;R
# LanguageWorkedWith                                         Java;Perl;Python;R;SQL
# MiscTechDesireNextYear                            Keras;Node.js;Pandas;TensorFlow
# MiscTechWorkedWith                  Keras;Node.js;Pandas;TensorFlow;Torch/PyTorch
# NEWCollabToolsDesireNextYear     Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# NEWCollabToolsWorkedWith        Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# NEWDevOps                                                                     NaN
# NEWDevOpsImpt                                                                 NaN
# NEWEdImpt                                                        Fairly important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                              Once a year
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                NaN
# NEWOtherComms                                                                 Yes
# NEWOvertime                                                                   NaN
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                              Amused
# NEWSOSites                      Stack Overflow (public Q&A for anyone who code...
# NEWStuck                        Meditate;Visit Stack Overflow;Go for a walk or...
# OpSys                                                                 Linux-based
# OrgSize                                                                       NaN
# PlatformDesireNextYear                        Android;Google Cloud Platform;Linux
# PlatformWorkedWith                                    Google Cloud Platform;Linux
# PurchaseWhat                                                                  NaN
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                            Yes, definitely
# SOPartFreq                                                   A few times per week
# SOVisitFreq                                                Multiple times per day
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  A social science (such as anthropology, psycho...
# WebframeDesireNextYear                                                        NaN
# WebframeWorkedWith                                                jQuery;React.js
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                   NaN
# YearsCode                                                                      35
# YearsCodePro                                                                  NaN
# Name: 56924, dtype: object
# 3251
# MainBranch                                            I code primarily as a hobby
# Hobbyist                                                                      Yes
# Age                                                                            62
# Age1stCode                                                                     18
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Finland
# CurrencyDesc                                                                  NaN
# CurrencySymbol                                                                NaN
# DatabaseDesireNextYear               Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# DatabaseWorkedWith                   Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# DevType                                                                       NaN
# EdLevel                           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                                Retired
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                                                                    NaN
# JobSat                                                                        NaN
# JobSeek                                                                       NaN
# LanguageDesireNextYear                                      HTML/CSS;Python;R;SQL
# LanguageWorkedWith                                          HTML/CSS;Python;R;SQL
# MiscTechDesireNextYear                       Apache Spark;Keras;Pandas;TensorFlow
# MiscTechWorkedWith                                                         Pandas
# NEWCollabToolsDesireNextYear                                               Github
# NEWCollabToolsWorkedWith                                                      NaN
# NEWDevOps                                                                     NaN
# NEWDevOpsImpt                                                                 NaN
# NEWEdImpt                                                          Very important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                     Once every few years
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                NaN
# NEWOtherComms                                                                 Yes
# NEWOvertime                                                                   NaN
# NEWPurchaseResearch                                                           NaN
# NEWPurpleLink                                                              Amused
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                                                     Visit Stack Overflow
# OpSys                                                                     Windows
# OrgSize                                                                       NaN
# PlatformDesireNextYear             AWS;Google Cloud Platform;Heroku;Linux;Windows
# PlatformWorkedWith                                                        Windows
# PurchaseWhat                                                                  NaN
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                              Yes, somewhat
# SOPartFreq                      I have never participated in Q&A on Stack Over...
# SOVisitFreq                                                Multiple times per day
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  A business discipline (such as accounting, fin...
# WebframeDesireNextYear                                                      Flask
# WebframeWorkedWith                                                          Flask
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                   NaN
# YearsCode                                                                       3
# YearsCodePro                                                                  NaN
# Name: 3251, dtype: object
# 19890
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                            61
# Age1stCode                                                                     21
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                    Canada
# CurrencyDesc                                                      Canadian dollar
# CurrencySymbol                                                                CAD
# DatabaseDesireNextYear                                                        NaN
# DatabaseWorkedWith                                           Microsoft SQL Server
# DevType                         Designer;Developer, desktop or enterprise appl...
# EdLevel                                       Associate degree (A.A., A.S., etc.)
# Employment                                                     Employed full-time
# Ethnicity                                                                     NaN
# Gender                                                                        NaN
# JobFactors                      Languages, frameworks, and other technologies ...
# JobSat                                                         Slightly satisfied
# JobSeek                         I’m not actively looking, but I am open to new...
# LanguageDesireNextYear                                                  Go;Kotlin
# LanguageWorkedWith                                                  C#;Python;VBA
# MiscTechDesireNextYear                                                        NaN
# MiscTechWorkedWith                                                 .NET;.NET Core
# NEWCollabToolsDesireNextYear                                                  NaN
# NEWCollabToolsWorkedWith                                                   Github
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                  Somewhat important
# NEWEdImpt                                                          Very important
# NEWJobHunt                      Wanting to work with new technologies;Growth o...
# NEWJobHuntResearch              Read company media, such as employee blogs or ...
# NEWLearn                                                              Once a year
# NEWOffTopic                                                                    No
# NEWOnboardGood                                                                Yes
# NEWOtherComms                                                                 Yes
# NEWOvertime                     Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                         Indifferent
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                        Go for a walk or other physical activity;Visit...
# OpSys                                                                     Windows
# OrgSize                                                  5,000 to 9,999 employees
# PlatformDesireNextYear                                                        NaN
# PlatformWorkedWith                                              Windows;WordPress
# PurchaseWhat                                                I have some influence
# Sexuality                                                                     NaN
# SOAccount                                                                     Yes
# SOComm                                                             No, not really
# SOPartFreq                                    Less than once per month or monthly
# SOVisitFreq                                       A few times per month or weekly
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                         NaN
# UndergradMajor                  Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                        NaN
# WebframeWorkedWith                                                            NaN
# WelcomeChange                            Somewhat less welcome now than last year
# WorkWeekHrs                                                                    40
# YearsCode                                                                      39
# YearsCodePro                                                                   29
# Name: 19890, dtype: object
# 57451
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                       No
# Age                                                                            61
# Age1stCode                                                                     19
# CompFreq                                                                   Yearly
# CompTotal                                                                  600000
# ConvertedComp                                                               64737
# Country                                                                    Norway
# CurrencyDesc                                                      Norwegian krone
# CurrencySymbol                                                                NOK
# DatabaseDesireNextYear                                                   Firebase
# DatabaseWorkedWith                          Microsoft SQL Server;MySQL;PostgreSQL
# DevType                                      Developer, front-end;Product manager
# EdLevel                         Some college/university study without earning ...
# Employment                                                     Employed full-time
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Flex time or a flexible schedule;Languages, fr...
# JobSat                                                             Very satisfied
# JobSeek                              I am not interested in new job opportunities
# LanguageDesireNextYear                                 Java;JavaScript;TypeScript
# LanguageWorkedWith                                                Java;JavaScript
# MiscTechDesireNextYear                                            Flutter;Node.js
# MiscTechWorkedWith                                                        Node.js
# NEWCollabToolsDesireNextYear                                               Github
# NEWCollabToolsWorkedWith        Jira;Github;Slack;Microsoft Teams;Trello;Googl...
# NEWDevOps                                                                     Yes
# NEWDevOpsImpt                                                 Extremely important
# NEWEdImpt                                                      Somewhat important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch              Read company media, such as employee blogs or ...
# NEWLearn                                                     Once every few years
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                 No
# NEWOtherComms                                                                 Yes
# NEWOvertime                     Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                         Indifferent
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                     Windows
# OrgSize                                                  1,000 to 4,999 employees
# PlatformDesireNextYear                                            Android;Windows
# PlatformWorkedWith                                                        Windows
# PurchaseWhat                                     I have a great deal of influence
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                 Not sure/can't remember
# SOComm                                                                    Neutral
# SOPartFreq                                                                    NaN
# SOVisitFreq                                       A few times per month or weekly
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                                                                NaN
# WebframeDesireNextYear                                                     Vue.js
# WebframeWorkedWith                                                       React.js
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    38
# YearsCode                                                                      42
# YearsCodePro                                                                   35
# Name: 57451, dtype: object
# 43830
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                            61
# Age1stCode                                                                     18
# CompFreq                                                                   Yearly
# CompTotal                                                                  125000
# ConvertedComp                                                              125000
# Country                                                             United States
# CurrencyDesc                                                 United States dollar
# CurrencySymbol                                                                USD
# DatabaseDesireNextYear                                                 PostgreSQL
# DatabaseWorkedWith                                       MariaDB;PostgreSQL;Redis
# DevType                         Designer;Developer, back-end;Developer, front-...
# EdLevel                         Some college/university study without earning ...
# Employment                      Independent contractor, freelancer, or self-em...
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Specific department or team I’d be working on;...
# JobSat                                                      Slightly dissatisfied
# JobSeek                         I’m not actively looking, but I am open to new...
# LanguageDesireNextYear           Bash/Shell/PowerShell;JavaScript;Perl;Python;SQL
# LanguageWorkedWith                        Bash/Shell/PowerShell;HTML/CSS;Perl;SQL
# MiscTechDesireNextYear                                                        NaN
# MiscTechWorkedWith                                                            NaN
# NEWCollabToolsDesireNextYear                                                  NaN
# NEWCollabToolsWorkedWith                                    Confluence;Jira;Slack
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                  Not very important
# NEWEdImpt                                      Not at all important/not necessary
# NEWJobHunt                      Having a bad day (or week or month) at work;Be...
# NEWJobHuntResearch              Company reviews from third party sites (e.g. G...
# NEWLearn                                                            Once a decade
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                 No
# NEWOtherComms                                                                 Yes
# NEWOvertime                     Occasionally: 1-2 days per quarter but less th...
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                              Amused
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                        Meditate;Call a coworker or friend;Go for a wa...
# OpSys                                                                 Linux-based
# OrgSize                         Just me - I am a freelancer, sole proprietor, ...
# PlatformDesireNextYear                                                      Linux
# PlatformWorkedWith                                    AWS;Linux;Windows;WordPress
# PurchaseWhat                                                                  NaN
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                             No, not at all
# SOPartFreq                      I have never participated in Q&A on Stack Over...
# SOVisitFreq                                   Less than once per month or monthly
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Fine arts or performing arts (such as graphic ...
# WebframeDesireNextYear                                                        NaN
# WebframeWorkedWith                                                            NaN
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    40
# YearsCode                                                                      43
# YearsCodePro                                                                   37
# Name: 43830, dtype: object
# 15907
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                       No
# Age                                                                            59
# Age1stCode                                                                     25
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                    Brazil
# CurrencyDesc                                                       Brazilian real
# CurrencySymbol                                                                BRL
# DatabaseDesireNextYear             Microsoft SQL Server;MongoDB;Oracle;PostgreSQL
# DatabaseWorkedWith                                              Oracle;PostgreSQL
# DevType                             Developer, desktop or enterprise applications
# EdLevel                           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                     Employed full-time
# Ethnicity                                                  Hispanic or Latino/a/x
# Gender                                                                        Man
# JobFactors                      Languages, frameworks, and other technologies ...
# JobSat                                                         Slightly satisfied
# JobSeek                                           I am actively looking for a job
# LanguageDesireNextYear                                           Python;R;SQL;VBA
# LanguageWorkedWith              Assembly;Bash/Shell/PowerShell;HTML/CSS;Java;J...
# MiscTechDesireNextYear                                                        NaN
# MiscTechWorkedWith                                                            NaN
# NEWCollabToolsDesireNextYear                                    Jira;Github;Slack
# NEWCollabToolsWorkedWith                                 Jira;Github;Slack;Trello
# NEWDevOps                                                                     Yes
# NEWDevOpsImpt                                                  Somewhat important
# NEWEdImpt                                                    Critically important
# NEWJobHunt                           Better work/life balance;Looking to relocate
# NEWJobHuntResearch              Read company media, such as employee blogs or ...
# NEWLearn                                                     Once every few years
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                 No
# NEWOtherComms                                                                  No
# NEWOvertime                     Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch                                                           NaN
# NEWPurpleLink                                                         Indifferent
# NEWSOSites                      Stack Overflow (public Q&A for anyone who code...
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                     Windows
# OrgSize                                                        10 to 19 employees
# PlatformDesireNextYear                                          AWS;Linux;Windows
# PlatformWorkedWith                                                    AWS;Windows
# PurchaseWhat                                        I have little or no influence
# Sexuality                                                                     NaN
# SOAccount                                                                     Yes
# SOComm                                                                    Neutral
# SOPartFreq                      I have never participated in Q&A on Stack Over...
# SOVisitFreq                                   Less than once per month or monthly
# SurveyEase                                             Neither easy nor difficult
# SurveyLength                                                             Too long
# Trans                                                                          No
# UndergradMajor                  Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                        NaN
# WebframeWorkedWith                                                            NaN
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    40
# YearsCode                                                                      35
# YearsCodePro                                                                   32
# Name: 15907, dtype: object
# 31302
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                            59
# Age1stCode                                                                     16
# CompFreq                                                                   Yearly
# CompTotal                                                                  650000
# ConvertedComp                                                               70132
# Country                                                                    Norway
# CurrencyDesc                                                      Norwegian krone
# CurrencySymbol                                                                NOK
# DatabaseDesireNextYear                                       Microsoft SQL Server
# DatabaseWorkedWith                                           Microsoft SQL Server
# DevType                                                     Developer, full-stack
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                     Employed full-time
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Flex time or a flexible schedule;Languages, fr...
# JobSat                                                             Very satisfied
# JobSeek                              I am not interested in new job opportunities
# LanguageDesireNextYear                                                        NaN
# LanguageWorkedWith              Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# MiscTechDesireNextYear                                                  .NET Core
# MiscTechWorkedWith                                                 .NET;.NET Core
# NEWCollabToolsDesireNextYear                                                  NaN
# NEWCollabToolsWorkedWith                                                      NaN
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                             Neutral
# NEWEdImpt                                                      Somewhat important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                            Once a decade
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                       Onboarding? What onboarding?
# NEWOtherComms                                                                 Yes
# NEWOvertime                     Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch             Start a free trial;Visit developer communities...
# NEWPurpleLink                                                   Hello, old friend
# NEWSOSites                      Stack Overflow (public Q&A for anyone who code...
# NEWStuck                        Meditate;Visit Stack Overflow;Go for a walk or...
# OpSys                                                                     Windows
# OrgSize                                                        10 to 19 employees
# PlatformDesireNextYear                                                    Windows
# PlatformWorkedWith                                                        Windows
# PurchaseWhat                                     I have a great deal of influence
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                              Yes, somewhat
# SOPartFreq                                                  Daily or almost daily
# SOVisitFreq                                                 Daily or almost daily
# SurveyEase                                             Neither easy nor difficult
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                               ASP.NET Core
# WebframeWorkedWith                                                   ASP.NET Core
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    40
# YearsCode                                                                      43
# YearsCodePro                                                                   20
# Name: 31302, dtype: object
# 49614
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                            58
# Age1stCode                                                                     17
# CompFreq                                                                   Yearly
# CompTotal                                                                  200000
# ConvertedComp                                                              200000
# Country                                                             United States
# CurrencyDesc                                                 United States dollar
# CurrencySymbol                                                                USD
# DatabaseDesireNextYear                                         MongoDB;PostgreSQL
# DatabaseWorkedWith                                             MongoDB;PostgreSQL
# DevType                         Developer, back-end;Developer, desktop or ente...
# EdLevel                           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                     Employed full-time
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Languages, frameworks, and other technologies ...
# JobSat                                                             Very satisfied
# JobSeek                              I am not interested in new job opportunities
# LanguageDesireNextYear                                        HTML/CSS;JavaScript
# LanguageWorkedWith                              Go;HTML/CSS;JavaScript;TypeScript
# MiscTechDesireNextYear                                                    Node.js
# MiscTechWorkedWith                                           Node.js;React Native
# NEWCollabToolsDesireNextYear         Github;Trello;Google Suite (Docs, Meet, etc)
# NEWCollabToolsWorkedWith        Confluence;Github;Gitlab;Trello;Google Suite (...
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                  Somewhat important
# NEWEdImpt                                                          Very important
# NEWJobHunt                      Better compensation;Wanting to work with new t...
# NEWJobHuntResearch                           Personal network - friends or family
# NEWLearn                                                              Once a year
# NEWOffTopic                                                                   Yes
# NEWOnboardGood                                                                 No
# NEWOtherComms                                                                 Yes
# NEWOvertime                                     Rarely: 1-2 days per year or less
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                   Hello, old friend
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                                             Watch help / tutorial videos
# OpSys                                                                       MacOS
# OrgSize                                                      100 to 499 employees
# PlatformDesireNextYear                                                      MacOS
# PlatformWorkedWith                                                          MacOS
# PurchaseWhat                                                I have some influence
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                 Not sure/can't remember
# SOComm                                                             No, not really
# SOPartFreq                                                                    NaN
# SOVisitFreq                                                  A few times per week
# SurveyEase                                                                   Easy
# SurveyLength                                                             Too long
# Trans                                                                          No
# UndergradMajor                  Computer science, computer engineering, or sof...
# WebframeDesireNextYear                                                    Express
# WebframeWorkedWith                                        Express;React.js;Vue.js
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    45
# YearsCode                                                                      42
# YearsCodePro                                                                   40
# Name: 49614, dtype: object
# 14140
# MainBranch                                            I code primarily as a hobby
# Hobbyist                                                                      Yes
# Age                                                                            57
# Age1stCode                                                                     25
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                            United Kingdom
# CurrencyDesc                                                                  NaN
# CurrencySymbol                                                                NaN
# DatabaseDesireNextYear                                              MariaDB;MySQL
# DatabaseWorkedWith                                                  MariaDB;MySQL
# DevType                                                                       NaN
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                                    NaN
# Ethnicity                                                                     NaN
# Gender                                                                        Man
# JobFactors                                                                    NaN
# JobSat                                                                        NaN
# JobSeek                                                                       NaN
# LanguageDesireNextYear          C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Objec...
# LanguageWorkedWith              C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Objec...
# MiscTechDesireNextYear                                      .NET;Node.js;Unity 3D
# MiscTechWorkedWith                                          .NET;Node.js;Unity 3D
# NEWCollabToolsDesireNextYear                                               Github
# NEWCollabToolsWorkedWith                                                   Github
# NEWDevOps                                                                     NaN
# NEWDevOpsImpt                                                                 NaN
# NEWEdImpt                                                    Critically important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                              Once a year
# NEWOffTopic                                                                   NaN
# NEWOnboardGood                                                                NaN
# NEWOtherComms                                                                 Yes
# NEWOvertime                                                                   NaN
# NEWPurchaseResearch             Start a free trial;Visit developer communities...
# NEWPurpleLink                                                         Indifferent
# NEWSOSites                      Stack Exchange (public Q&A for a variety of to...
# NEWStuck                        Visit Stack Overflow;Watch help / tutorial vid...
# OpSys                                                                     Windows
# ...
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Computer science, computer engineering, or sof...
# WebframeDesireNextYear                                                   React.js
# WebframeWorkedWith                                                       React.js
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    39
# YearsCode                                                                       8
# YearsCodePro                                                                    3
# Name: 14589, dtype: object
# 753
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                            24
# Age1stCode                                                                      8
# CompFreq                                                                  Monthly
# CompTotal                                                                   23000
# ConvertedComp                                                                3852
# Country                                                                     India
# CurrencyDesc                                                         Indian rupee
# CurrencySymbol                                                                INR
# DatabaseDesireNextYear                                                 PostgreSQL
# DatabaseWorkedWith                                             MongoDB;PostgreSQL
# DevType                                               Developer, game or graphics
# EdLevel                         Some college/university study without earning ...
# Employment                                                     Employed full-time
# Ethnicity                                                                     NaN
# Gender                                                                        Man
# JobFactors                      Specific department or team I’d be working on;...
# JobSat                                                          Very dissatisfied
# JobSeek                         I’m not actively looking, but I am open to new...
# LanguageDesireNextYear                                              C++;Go;Python
# LanguageWorkedWith                                             Go;HTML/CSS;Python
# MiscTechDesireNextYear                                              Unreal Engine
# MiscTechWorkedWith                                                            NaN
# NEWCollabToolsDesireNextYear                        Confluence;Jira;Github;Gitlab
# NEWCollabToolsWorkedWith                            Confluence;Jira;Github;Gitlab
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                             Neutral
# NEWEdImpt                                                    Critically important
# NEWJobHunt                      Having a bad day (or week or month) at work;Cu...
# NEWJobHuntResearch              Read company media, such as employee blogs or ...
# NEWLearn                                                              Once a year
# NEWOffTopic                                                                    No
# NEWOnboardGood                                                                Yes
# NEWOtherComms                                                                 Yes
# NEWOvertime                     Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch                                                           NaN
# NEWPurpleLink                                                         Indifferent
# NEWSOSites                      Stack Overflow (public Q&A for anyone who code...
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                 Linux-based
# OrgSize                                                                       NaN
# PlatformDesireNextYear                                                      Linux
# PlatformWorkedWith                                                   Docker;Linux
# PurchaseWhat                                        I have little or no influence
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                              Yes, somewhat
# SOPartFreq                                    Less than once per month or monthly
# SOVisitFreq                                                 Daily or almost daily
# SurveyEase                                                                   Easy
# SurveyLength                                                             Too long
# Trans                                                                          No
# UndergradMajor                  Fine arts or performing arts (such as graphic ...
# WebframeDesireNextYear                                                      Flask
# WebframeWorkedWith                                                   Django;Flask
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    48
# YearsCode                                                                       8
# YearsCodePro                                                                    2
# Name: 753, dtype: object
# 51186
# MainBranch                      I am not primarily a developer, but I write co...
# Hobbyist                                                                      Yes
# Age                                                                            24
# Age1stCode                                                                     15
# CompFreq                                                                   Yearly
# CompTotal                                                                   26000
# ConvertedComp                                                               26000
# Country                                                             United States
# CurrencyDesc                                                 United States dollar
# CurrencySymbol                                                                USD
# DatabaseDesireNextYear                                                        NaN
# DatabaseWorkedWith                                                            NaN
# DevType                                             Academic researcher;Scientist
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                     Employed full-time
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Industry that I’d be working in;Flex time or a...
# JobSat                                                         Slightly satisfied
# JobSeek                         I’m not actively looking, but I am open to new...
# LanguageDesireNextYear           Bash/Shell/PowerShell;C++;Python;Rust;TypeScript
# LanguageWorkedWith                               Bash/Shell/PowerShell;Python;VBA
# MiscTechDesireNextYear                                   TensorFlow;Unreal Engine
# MiscTechWorkedWith                                                            NaN
# NEWCollabToolsDesireNextYear                                               Github
# NEWCollabToolsWorkedWith                                                      NaN
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                             Neutral
# NEWEdImpt                                                    Critically important
# NEWJobHunt                      Having a bad day (or week or month) at work;Cu...
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                              Once a year
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                       Onboarding? What onboarding?
# NEWOtherComms                                                                  No
# NEWOvertime                     Occasionally: 1-2 days per quarter but less th...
# NEWPurchaseResearch                                                           NaN
# NEWPurpleLink                                                   Hello, old friend
# NEWSOSites                      Stack Overflow (public Q&A for anyone who code...
# NEWStuck                        Play games;Visit Stack Overflow;Do other work ...
# OpSys                                                                     Windows
# OrgSize                                                        20 to 99 employees
# PlatformDesireNextYear                                              Linux;Windows
# PlatformWorkedWith                                                  Linux;Windows
# PurchaseWhat                                        I have little or no influence
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                      No
# SOComm                                                             No, not at all
# SOPartFreq                                                                    NaN
# SOVisitFreq                                                Multiple times per day
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                        NaN
# WebframeWorkedWith                                                            NaN
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                    40
# YearsCode                                                                       9
# YearsCodePro                                                                    3
# Name: 51186, dtype: object
# 61764
# MainBranch                                 I am a student who is learning to code
# Hobbyist                                                                       No
# Age                                                                            24
# Age1stCode                                                                     23
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Nigeria
# CurrencyDesc                                                                  NaN
# CurrencySymbol                                                                NaN
# DatabaseDesireNextYear                                MongoDB;MySQL;Oracle;SQLite
# DatabaseWorkedWith                                                            NaN
# DevType                                                                       NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Employment                                                                Student
# Ethnicity                                             Black or of African descent
# Gender                                                                      Woman
# JobFactors                      Languages, frameworks, and other technologies ...
# JobSat                                                                        NaN
# JobSeek                                           I am actively looking for a job
# LanguageDesireNextYear                                      JavaScript;Python;SQL
# LanguageWorkedWith                                                            NaN
# MiscTechDesireNextYear                                      Node.js;Torch/PyTorch
# MiscTechWorkedWith                                                            NaN
# NEWCollabToolsDesireNextYear                Github;Slack;Stack Overflow for Teams
# NEWCollabToolsWorkedWith                                                      NaN
# NEWDevOps                                                                     NaN
# NEWDevOpsImpt                                                                 NaN
# NEWEdImpt                                                                     NaN
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                                      NaN
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                NaN
# NEWOtherComms                                                                 Yes
# NEWOvertime                                                                   NaN
# NEWPurchaseResearch             Ask developers I know/work with;Visit develope...
# NEWPurpleLink                                                         Indifferent
# NEWSOSites                      Stack Overflow (public Q&A for anyone who code...
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                     Windows
# OrgSize                                                                       NaN
# PlatformDesireNextYear                                          Windows;WordPress
# PlatformWorkedWith                                                            NaN
# PurchaseWhat                                                                  NaN
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                     Yes
# SOComm                                                                    Neutral
# SOPartFreq                                    Less than once per month or monthly
# SOVisitFreq                                                Multiple times per day
# SurveyEase                                                                   Easy
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                                                                NaN
# WebframeDesireNextYear                                      Django;Flask;React.js
# WebframeWorkedWith                                                            NaN
# WelcomeChange                   Not applicable - I did not use Stack Overflow ...
# WorkWeekHrs                                                                   NaN
# YearsCode                                                        Less than 1 year
# YearsCodePro                                                                  NaN
# Name: 61764, dtype: object
# 2483
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
inversed_df = pd.DataFrame({idx: values for idx, values in survey_df.iterrows()})
inversed_df.shape # 转置矩阵：从(1000, 60)到(60, 1000)
# Out:
# (60, 1000)

# %%
inversed_df
# Out:
#                                                                           36576  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                          67
# Age1stCode                                                                   18
# CompFreq                                                                Monthly
# CompTotal                                                                 35000
# ConvertedComp                                                              6600
# Country                                                      Russian Federation
# CurrencyDesc                                                      Russian ruble
# CurrencySymbol                                                              RUB
# DatabaseDesireNextYear                                                   SQLite
# DatabaseWorkedWith                                                       SQLite
# DevType                       Developer, back-end;Developer, desktop or ente...
# EdLevel                              Other doctoral degree (Ph.D., Ed.D., etc.)
# Employment                                                   Employed full-time
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                    Industry that I’d be working in;Languages, fra...
# JobSat                                                       Slightly satisfied
# JobSeek                       I’m not actively looking, but I am open to new...
# LanguageDesireNextYear                                            C;Python;Rust
# LanguageWorkedWith                                                   C;Python;R
# MiscTechDesireNextYear                                                   Pandas
# MiscTechWorkedWith                                                       Pandas
# NEWCollabToolsDesireNextYear                                             Github
# NEWCollabToolsWorkedWith                                                 Github
# NEWDevOps                                                                   Yes
# NEWDevOpsImpt                                                Somewhat important
# NEWEdImpt                                                      Fairly important
# NEWJobHunt                                                  Better compensation
# NEWJobHuntResearch            Read company media, such as employee blogs or ...
# NEWLearn                                                   Once every few years
# NEWOffTopic                                                                  No
# NEWOnboardGood                                     Onboarding? What onboarding?
# NEWOtherComms                                                               Yes
# NEWOvertime                   Occasionally: 1-2 days per quarter but less th...
# NEWPurchaseResearch                                                         NaN
# NEWPurpleLink                                                           Annoyed
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                      Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                               Linux-based
# OrgSize                                                1,000 to 4,999 employees
# PlatformDesireNextYear                                       Linux;Raspberry Pi
# PlatformWorkedWith                                                        Linux
# PurchaseWhat                                      I have little or no influence
# Sexuality                                               Straight / Heterosexual
# SOAccount                                                                   Yes
# SOComm                                                            Yes, somewhat
# SOPartFreq                                                 A few times per week
# SOVisitFreq                                                A few times per week
# SurveyEase                                           Neither easy nor difficult
# SurveyLength                                              Appropriate in length
# Trans                                                                        No
# UndergradMajor                Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                                          NaN
# WelcomeChange                          Somewhat more welcome now than last year
# WorkWeekHrs                                                                  40
# YearsCode                                                                    50
# YearsCodePro                                                                 45
#
#                                                                           56924  \
# MainBranch                    I used to be a developer by profession, but no...
# Hobbyist                                                                    Yes
# Age                                                                          63
# Age1stCode                                                                   24
# CompFreq                                                                    NaN
# CompTotal                                                                   NaN
# ConvertedComp                                                               NaN
# Country                                                                  Sweden
# CurrencyDesc                                                                NaN
# CurrencySymbol                                                              NaN
# DatabaseDesireNextYear                                               PostgreSQL
# DatabaseWorkedWith                                  MariaDB;MySQL;Oracle;SQLite
# DevType                                                                     NaN
# EdLevel                            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                              Retired
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                                                                  NaN
# JobSat                                                                      NaN
# JobSeek                                                                     NaN
# LanguageDesireNextYear              Haskell;Java;JavaScript;Julia;Perl;Python;R
# LanguageWorkedWith                                       Java;Perl;Python;R;SQL
# MiscTechDesireNextYear                          Keras;Node.js;Pandas;TensorFlow
# MiscTechWorkedWith                Keras;Node.js;Pandas;TensorFlow;Torch/PyTorch
# NEWCollabToolsDesireNextYear   Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# NEWCollabToolsWorkedWith      Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# NEWDevOps                                                                   NaN
# NEWDevOpsImpt                                                               NaN
# NEWEdImpt                                                      Fairly important
# NEWJobHunt                                                                  NaN
# NEWJobHuntResearch                                                          NaN
# NEWLearn                                                            Once a year
# NEWOffTopic                                                            Not sure
# NEWOnboardGood                                                              NaN
# NEWOtherComms                                                               Yes
# NEWOvertime                                                                 NaN
# NEWPurchaseResearch           Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                            Amused
# NEWSOSites                    Stack Overflow (public Q&A for anyone who code...
# NEWStuck                      Meditate;Visit Stack Overflow;Go for a walk or...
# OpSys                                                               Linux-based
# OrgSize                                                                     NaN
# PlatformDesireNextYear                      Android;Google Cloud Platform;Linux
# PlatformWorkedWith                                  Google Cloud Platform;Linux
# PurchaseWhat                                                                NaN
# Sexuality                                               Straight / Heterosexual
# SOAccount                                                                   Yes
# SOComm                                                          Yes, definitely
# SOPartFreq                                                 A few times per week
# SOVisitFreq                                              Multiple times per day
# SurveyEase                                                                 Easy
# SurveyLength                                              Appropriate in length
# Trans                                                                        No
# UndergradMajor                A social science (such as anthropology, psycho...
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                              jQuery;React.js
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                 NaN
# YearsCode                                                                    35
# YearsCodePro                                                                NaN
#
#                                                                           3251   \
# MainBranch                                          I code primarily as a hobby
# Hobbyist                                                                    Yes
# Age                                                                          62
# Age1stCode                                                                   18
# CompFreq                                                                    NaN
# CompTotal                                                                   NaN
# ConvertedComp                                                               NaN
# Country                                                                 Finland
# CurrencyDesc                                                                NaN
# CurrencySymbol                                                              NaN
# DatabaseDesireNextYear             Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# DatabaseWorkedWith                 Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# DevType                                                                     NaN
# EdLevel                         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                              Retired
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                                                                  NaN
# JobSat                                                                      NaN
# JobSeek                                                                     NaN
# LanguageDesireNextYear                                    HTML/CSS;Python;R;SQL
# LanguageWorkedWith                                        HTML/CSS;Python;R;SQL
# MiscTechDesireNextYear                     Apache Spark;Keras;Pandas;TensorFlow
# MiscTechWorkedWith                                                       Pandas
# NEWCollabToolsDesireNextYear                                             Github
# NEWCollabToolsWorkedWith                                                    NaN
# NEWDevOps                                                                   NaN
# NEWDevOpsImpt                                                               NaN
# NEWEdImpt                                                        Very important
# NEWJobHunt                                                                  NaN
# NEWJobHuntResearch                                                          NaN
# NEWLearn                                                   Once every few years
# NEWOffTopic                                                            Not sure
# NEWOnboardGood                                                              NaN
# NEWOtherComms                                                               Yes
# NEWOvertime                                                                 NaN
# NEWPurchaseResearch                                                         NaN
# NEWPurpleLink                                                            Amused
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                                                   Visit Stack Overflow
# OpSys                                                                   Windows
# OrgSize                                                                     NaN
# PlatformDesireNextYear           AWS;Google Cloud Platform;Heroku;Linux;Windows
# PlatformWorkedWith                                                      Windows
# PurchaseWhat                                                                NaN
# Sexuality                                               Straight / Heterosexual
# SOAccount                                                                   Yes
# SOComm                                                            Yes, somewhat
# SOPartFreq                    I have never participated in Q&A on Stack Over...
# SOVisitFreq                                              Multiple times per day
# SurveyEase                                                                 Easy
# SurveyLength                                              Appropriate in length
# Trans                                                                        No
# UndergradMajor                A business discipline (such as accounting, fin...
# WebframeDesireNextYear                                                    Flask
# WebframeWorkedWith                                                        Flask
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                 NaN
# YearsCode                                                                     3
# YearsCodePro                                                                NaN
#
#                                                                           19890  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                          61
# Age1stCode                                                                   21
# CompFreq                                                                    NaN
# CompTotal                                                                   NaN
# ConvertedComp                                                               NaN
# Country                                                                  Canada
# CurrencyDesc                                                    Canadian dollar
# CurrencySymbol                                                              CAD
# DatabaseDesireNextYear                                                      NaN
# DatabaseWorkedWith                                         Microsoft SQL Server
# DevType                       Designer;Developer, desktop or enterprise appl...
# EdLevel                                     Associate degree (A.A., A.S., etc.)
# Employment                                                   Employed full-time
# Ethnicity                                                                   NaN
# Gender                                                                      NaN
# JobFactors                    Languages, frameworks, and other technologies ...
# JobSat                                                       Slightly satisfied
# JobSeek                       I’m not actively looking, but I am open to new...
# LanguageDesireNextYear                                                Go;Kotlin
# LanguageWorkedWith                                                C#;Python;VBA
# MiscTechDesireNextYear                                                      NaN
# MiscTechWorkedWith                                               .NET;.NET Core
# NEWCollabToolsDesireNextYear                                                NaN
# NEWCollabToolsWorkedWith                                                 Github
# NEWDevOps                                                                    No
# NEWDevOpsImpt                                                Somewhat important
# NEWEdImpt                                                        Very important
# NEWJobHunt                    Wanting to work with new technologies;Growth o...
# NEWJobHuntResearch            Read company media, such as employee blogs or ...
# NEWLearn                                                            Once a year
# NEWOffTopic                                                                  No
# NEWOnboardGood                                                              Yes
# NEWOtherComms                                                               Yes
# NEWOvertime                   Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch           Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                       Indifferent
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                      Go for a walk or other physical activity;Visit...
# OpSys                                                                   Windows
# OrgSize                                                5,000 to 9,999 employees
# PlatformDesireNextYear                                                      NaN
# PlatformWorkedWith                                            Windows;WordPress
# PurchaseWhat                                              I have some influence
# Sexuality                                                                   NaN
# SOAccount                                                                   Yes
# SOComm                                                           No, not really
# SOPartFreq                                  Less than once per month or monthly
# SOVisitFreq                                     A few times per month or weekly
# SurveyEase                                                                 Easy
# SurveyLength                                              Appropriate in length
# Trans                                                                       NaN
# UndergradMajor                Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                                          NaN
# WelcomeChange                          Somewhat less welcome now than last year
# WorkWeekHrs                                                                  40
# YearsCode                                                                    39
# YearsCodePro                                                                 29
#
#                                                                           57451  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                     No
# Age                                                                          61
# Age1stCode                                                                   19
# CompFreq                                                                 Yearly
# CompTotal                                                                600000
# ConvertedComp                                                             64737
# Country                                                                  Norway
# CurrencyDesc                                                    Norwegian krone
# CurrencySymbol                                                              NOK
# DatabaseDesireNextYear                                                 Firebase
# DatabaseWorkedWith                        Microsoft SQL Server;MySQL;PostgreSQL
# DevType                                    Developer, front-end;Product manager
# EdLevel                       Some college/university study without earning ...
# Employment                                                   Employed full-time
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                    Flex time or a flexible schedule;Languages, fr...
# JobSat                                                           Very satisfied
# JobSeek                            I am not interested in new job opportunities
# LanguageDesireNextYear                               Java;JavaScript;TypeScript
# LanguageWorkedWith                                              Java;JavaScript
# MiscTechDesireNextYear                                          Flutter;Node.js
# MiscTechWorkedWith                                                      Node.js
# NEWCollabToolsDesireNextYear                                             Github
# NEWCollabToolsWorkedWith      Jira;Github;Slack;Microsoft Teams;Trello;Googl...
# NEWDevOps                                                                   Yes
# NEWDevOpsImpt                                               Extremely important
# NEWEdImpt                                                    Somewhat important
# NEWJobHunt                                                                  NaN
# NEWJobHuntResearch            Read company media, such as employee blogs or ...
# NEWLearn                                                   Once every few years
# NEWOffTopic                                                            Not sure
# NEWOnboardGood                                                               No
# NEWOtherComms                                                               Yes
# NEWOvertime                   Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch           Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                       Indifferent
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                      Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                   Windows
# OrgSize                                                1,000 to 4,999 employees
# PlatformDesireNextYear                                          Android;Windows
# PlatformWorkedWith                                                      Windows
# PurchaseWhat                                   I have a great deal of influence
# Sexuality                                               Straight / Heterosexual
# SOAccount                                               Not sure/can't remember
# SOComm                                                                  Neutral
# SOPartFreq                                                                  NaN
# SOVisitFreq                                     A few times per month or weekly
# SurveyEase                                                                 Easy
# SurveyLength                                              Appropriate in length
# Trans                                                                        No
# UndergradMajor                                                              NaN
# WebframeDesireNextYear                                                   Vue.js
# WebframeWorkedWith                                                     React.js
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                  38
# YearsCode                                                                    42
# YearsCodePro                                                                 35
#
#                                                                           43830  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                          61
# Age1stCode                                                                   18
# CompFreq                                                                 Yearly
# CompTotal                                                                125000
# ConvertedComp                                                            125000
# Country                                                           United States
# CurrencyDesc                                               United States dollar
# CurrencySymbol                                                              USD
# DatabaseDesireNextYear                                               PostgreSQL
# DatabaseWorkedWith                                     MariaDB;PostgreSQL;Redis
# DevType                       Designer;Developer, back-end;Developer, front-...
# EdLevel                       Some college/university study without earning ...
# Employment                    Independent contractor, freelancer, or self-em...
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                    Specific department or team I’d be working on;...
# JobSat                                                    Slightly dissatisfied
# JobSeek                       I’m not actively looking, but I am open to new...
# LanguageDesireNextYear         Bash/Shell/PowerShell;JavaScript;Perl;Python;SQL
# LanguageWorkedWith                      Bash/Shell/PowerShell;HTML/CSS;Perl;SQL
# MiscTechDesireNextYear                                                      NaN
# MiscTechWorkedWith                                                          NaN
# NEWCollabToolsDesireNextYear                                                NaN
# NEWCollabToolsWorkedWith                                  Confluence;Jira;Slack
# NEWDevOps                                                                    No
# NEWDevOpsImpt                                                Not very important
# NEWEdImpt                                    Not at all important/not necessary
# NEWJobHunt                    Having a bad day (or week or month) at work;Be...
# NEWJobHuntResearch            Company reviews from third party sites (e.g. G...
# NEWLearn                                                          Once a decade
# NEWOffTopic                                                            Not sure
# NEWOnboardGood                                                               No
# NEWOtherComms                                                               Yes
# NEWOvertime                   Occasionally: 1-2 days per quarter but less th...
# NEWPurchaseResearch           Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                            Amused
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                      Meditate;Call a coworker or friend;Go for a wa...
# OpSys                                                               Linux-based
# OrgSize                       Just me - I am a freelancer, sole proprietor, ...
# PlatformDesireNextYear                                                    Linux
# PlatformWorkedWith                                  AWS;Linux;Windows;WordPress
# PurchaseWhat                                                                NaN
# Sexuality                                               Straight / Heterosexual
# SOAccount                                                                   Yes
# SOComm                                                           No, not at all
# SOPartFreq                    I have never participated in Q&A on Stack Over...
# SOVisitFreq                                 Less than once per month or monthly
# SurveyEase                                                                 Easy
# SurveyLength                                              Appropriate in length
# Trans                                                                        No
# UndergradMajor                Fine arts or performing arts (such as graphic ...
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                                          NaN
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                  40
# YearsCode                                                                    43
# YearsCodePro                                                                 37
#
#                                                                           15907  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                     No
# Age                                                                          59
# Age1stCode                                                                   25
# CompFreq                                                                Monthly
# CompTotal                                                                   NaN
# ConvertedComp                                                               NaN
# Country                                                                  Brazil
# CurrencyDesc                                                     Brazilian real
# CurrencySymbol                                                              BRL
# DatabaseDesireNextYear           Microsoft SQL Server;MongoDB;Oracle;PostgreSQL
# DatabaseWorkedWith                                            Oracle;PostgreSQL
# DevType                           Developer, desktop or enterprise applications
# EdLevel                         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                   Employed full-time
# Ethnicity                                                Hispanic or Latino/a/x
# Gender                                                                      Man
# JobFactors                    Languages, frameworks, and other technologies ...
# JobSat                                                       Slightly satisfied
# JobSeek                                         I am actively looking for a job
# LanguageDesireNextYear                                         Python;R;SQL;VBA
# LanguageWorkedWith            Assembly;Bash/Shell/PowerShell;HTML/CSS;Java;J...
# MiscTechDesireNextYear                                                      NaN
# MiscTechWorkedWith                                                          NaN
# NEWCollabToolsDesireNextYear                                  Jira;Github;Slack
# NEWCollabToolsWorkedWith                               Jira;Github;Slack;Trello
# NEWDevOps                                                                   Yes
# NEWDevOpsImpt                                                Somewhat important
# NEWEdImpt                                                  Critically important
# NEWJobHunt                         Better work/life balance;Looking to relocate
# NEWJobHuntResearch            Read company media, such as employee blogs or ...
# NEWLearn                                                   Once every few years
# NEWOffTopic                                                            Not sure
# NEWOnboardGood                                                               No
# NEWOtherComms                                                                No
# NEWOvertime                   Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch                                                         NaN
# NEWPurpleLink                                                       Indifferent
# NEWSOSites                    Stack Overflow (public Q&A for anyone who code...
# NEWStuck                      Call a coworker or friend;Visit Stack Overflow...
# OpSys                                                                   Windows
# OrgSize                                                      10 to 19 employees
# PlatformDesireNextYear                                        AWS;Linux;Windows
# PlatformWorkedWith                                                  AWS;Windows
# PurchaseWhat                                      I have little or no influence
# Sexuality                                                                   NaN
# SOAccount                                                                   Yes
# SOComm                                                                  Neutral
# SOPartFreq                    I have never participated in Q&A on Stack Over...
# SOVisitFreq                                 Less than once per month or monthly
# SurveyEase                                           Neither easy nor difficult
# SurveyLength                                                           Too long
# Trans                                                                        No
# UndergradMajor                Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                                          NaN
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                  40
# YearsCode                                                                    35
# YearsCodePro                                                                 32
#
#                                                                           31302  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                          59
# Age1stCode                                                                   16
# CompFreq                                                                 Yearly
# CompTotal                                                                650000
# ConvertedComp                                                             70132
# Country                                                                  Norway
# CurrencyDesc                                                    Norwegian krone
# CurrencySymbol                                                              NOK
# DatabaseDesireNextYear                                     Microsoft SQL Server
# DatabaseWorkedWith                                         Microsoft SQL Server
# DevType                                                   Developer, full-stack
# EdLevel                            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                   Employed full-time
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                    Flex time or a flexible schedule;Languages, fr...
# JobSat                                                           Very satisfied
# JobSeek                            I am not interested in new job opportunities
# LanguageDesireNextYear                                                      NaN
# LanguageWorkedWith            Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# MiscTechDesireNextYear                                                .NET Core
# MiscTechWorkedWith                                               .NET;.NET Core
# NEWCollabToolsDesireNextYear                                                NaN
# NEWCollabToolsWorkedWith                                                    NaN
# NEWDevOps                                                                    No
# NEWDevOpsImpt                                                           Neutral
# NEWEdImpt                                                    Somewhat important
# NEWJobHunt                                                                  NaN
# NEWJobHuntResearch                                                          NaN
# NEWLearn                                                          Once a decade
# NEWOffTopic                                                            Not sure
# NEWOnboardGood                                     Onboarding? What onboarding?
# NEWOtherComms                                                               Yes
# NEWOvertime                   Sometimes: 1-2 days per month but less than we...
# NEWPurchaseResearch           Start a free trial;Visit developer communities...
# NEWPurpleLink                                                 Hello, old friend
# NEWSOSites                    Stack Overflow (public Q&A for anyone who code...
# NEWStuck                      Meditate;Visit Stack Overflow;Go for a walk or...
# OpSys                                                                   Windows
# OrgSize                                                      10 to 19 employees
# PlatformDesireNextYear                                                  Windows
# PlatformWorkedWith                                                      Windows
# PurchaseWhat                                   I have a great deal of influence
# Sexuality                                               Straight / Heterosexual
# SOAccount                                                                   Yes
# SOComm                                                            Yes, somewhat
# SOPartFreq                                                Daily or almost daily
# SOVisitFreq                                               Daily or almost daily
# SurveyEase                                           Neither easy nor difficult
# SurveyLength                                              Appropriate in length
# Trans                                                                        No
# UndergradMajor                Another engineering discipline (such as civil,...
# WebframeDesireNextYear                                             ASP.NET Core
# WebframeWorkedWith                                                 ASP.NET Core
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                  40
# YearsCode                                                                    43
# YearsCodePro                                                                 20
#
#                                                                           49614  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                          58
# Age1stCode                                                                   17
# CompFreq                                                                 Yearly
# CompTotal                                                                200000
# ConvertedComp                                                            200000
# Country                                                           United States
# CurrencyDesc                                               United States dollar
# CurrencySymbol                                                              USD
# DatabaseDesireNextYear                                       MongoDB;PostgreSQL
# DatabaseWorkedWith                                           MongoDB;PostgreSQL
# DevType                       Developer, back-end;Developer, desktop or ente...
# EdLevel                         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                   Employed full-time
# Ethnicity                                          White or of European descent
# Gender                                                                      Man
# JobFactors                    Languages, frameworks, and other technologies ...
# JobSat                                                           Very satisfied
# JobSeek                            I am not interested in new job opportunities
# LanguageDesireNextYear                                      HTML/CSS;JavaScript
# LanguageWorkedWith                            Go;HTML/CSS;JavaScript;TypeScript
# MiscTechDesireNextYear                                                  Node.js
# MiscTechWorkedWith                                         Node.js;React Native
# NEWCollabToolsDesireNextYear       Github;Trello;Google Suite (Docs, Meet, etc)
# NEWCollabToolsWorkedWith      Confluence;Github;Gitlab;Trello;Google Suite (...
# NEWDevOps                                                                    No
# NEWDevOpsImpt                                                Somewhat important
# NEWEdImpt                                                        Very important
# NEWJobHunt                    Better compensation;Wanting to work with new t...
# NEWJobHuntResearch                         Personal network - friends or family
# NEWLearn                                                            Once a year
# NEWOffTopic                                                                 Yes
# NEWOnboardGood                                                               No
# NEWOtherComms                                                               Yes
# NEWOvertime                                   Rarely: 1-2 days per year or less
# NEWPurchaseResearch           Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                 Hello, old friend
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                                           Watch help / tutorial videos
# OpSys                                                                     MacOS
# OrgSize                                                    100 to 499 employees
# PlatformDesireNextYear                                                    MacOS
# PlatformWorkedWith                                                        MacOS
# PurchaseWhat                                              I have some influence
# Sexuality                                               Straight / Heterosexual
# SOAccount                                               Not sure/can't remember
# SOComm                                                           No, not really
# SOPartFreq                                                                  NaN
# SOVisitFreq                                                A few times per week
# SurveyEase                                                                 Easy
# SurveyLength                                                           Too long
# Trans                                                                        No
# UndergradMajor                Computer science, computer engineering, or sof...
# WebframeDesireNextYear                                                  Express
# WebframeWorkedWith                                      Express;React.js;Vue.js
# WelcomeChange                           Just as welcome now as I felt last year
# WorkWeekHrs                                                                  45
# YearsCode                                                                    42
# YearsCodePro                                                                 40
#
#                                                                           14140  \
# MainBranch                                          I code primarily as a hobby
# Hobbyist                                                                    Yes
# Age                                                                          57
# Age1stCode                                                                   25
# CompFreq                                                                    NaN
# CompTotal                                                                   NaN
# ConvertedComp                                                               NaN
# Country                                                          United Kingdom
# CurrencyDesc                                                                NaN
# CurrencySymbol                                                              NaN
# DatabaseDesireNextYear                                            MariaDB;MySQL
# DatabaseWorkedWith                                                MariaDB;MySQL
# DevType                                                                     NaN
# EdLevel                            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Employment                                                                  NaN
# Ethnicity                                                                   NaN
# Gender                                                                      Man
# JobFactors                                                                  NaN
# JobSat                                                                      NaN
# JobSeek                                                                     NaN
# LanguageDesireNextYear        C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Objec...
# LanguageWorkedWith            C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;Objec...
# MiscTechDesireNextYear                                    .NET;Node.js;Unity 3D
# MiscTechWorkedWith                                        .NET;Node.js;Unity 3D
# NEWCollabToolsDesireNextYear                                             Github
# NEWCollabToolsWorkedWith                                                 Github
# NEWDevOps                                                                   NaN
# NEWDevOpsImpt                                                               NaN
# ...
# MiscTechDesireNextYear                                                      NaN
# MiscTechWorkedWith                              Node.js;React Native;TensorFlow
# NEWCollabToolsDesireNextYear                                                NaN
# NEWCollabToolsWorkedWith      Confluence;Jira;Github;Google Suite (Docs, Mee...
# NEWDevOps                                                                   NaN
# NEWDevOpsImpt                                                               NaN
# NEWEdImpt                                                                   NaN
# NEWJobHunt                                                                  NaN
# NEWJobHuntResearch                                                          NaN
# NEWLearn                                                       Every few months
# NEWOffTopic                                                                 NaN
# NEWOnboardGood                                                              NaN
# NEWOtherComms                                                               Yes
# NEWOvertime                                                                 NaN
# NEWPurchaseResearch           Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                            Amused
# NEWSOSites                     Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                      Watch help / tutorial videos;Do other work and...
# OpSys                                                                     MacOS
# OrgSize                                                                     NaN
# PlatformDesireNextYear                                                      NaN
# PlatformWorkedWith                                        Google Cloud Platform
# PurchaseWhat                                   I have a great deal of influence
# Sexuality                                                                   NaN
# SOAccount                                                                   Yes
# SOComm                                                                  Neutral
# SOPartFreq                    I have never participated in Q&A on Stack Over...
# SOVisitFreq                                 Less than once per month or monthly
# SurveyEase                                                                  NaN
# SurveyLength                                                                NaN
# Trans                                                                       NaN
# UndergradMajor                                                              NaN
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                                     React.js
# WelcomeChange                                                               NaN
# WorkWeekHrs                                                                 NaN
# YearsCode                                                                   NaN
# YearsCodePro                                                                NaN
#
#                                                        64744  \
# MainBranch                    I am a developer by profession
# Hobbyist                                                 Yes
# Age                                                      NaN
# Age1stCode                                               NaN
# CompFreq                                                 NaN
# CompTotal                                                NaN
# ConvertedComp                                            NaN
# Country                                           Costa Rica
# CurrencyDesc                                             NaN
# CurrencySymbol                                           NaN
# DatabaseDesireNextYear                                   NaN
# DatabaseWorkedWith                                       NaN
# DevType                                                  NaN
# EdLevel                                                  NaN
# Employment                                Employed full-time
# Ethnicity                                                NaN
# Gender                                                   NaN
# JobFactors                                               NaN
# JobSat                                                   NaN
# JobSeek                                                  NaN
# LanguageDesireNextYear                                   NaN
# LanguageWorkedWith                                       NaN
# MiscTechDesireNextYear                                   NaN
# MiscTechWorkedWith                                       NaN
# NEWCollabToolsDesireNextYear                             NaN
# NEWCollabToolsWorkedWith                                 NaN
# NEWDevOps                                                NaN
# NEWDevOpsImpt                                            NaN
# NEWEdImpt                                                NaN
# NEWJobHunt                                               NaN
# NEWJobHuntResearch                                       NaN
# NEWLearn                                                 NaN
# NEWOffTopic                                              NaN
# NEWOnboardGood                                           NaN
# NEWOtherComms                                            NaN
# NEWOvertime                                              NaN
# NEWPurchaseResearch                                      NaN
# NEWPurpleLink                                            NaN
# NEWSOSites                                               NaN
# NEWStuck                                                 NaN
# OpSys                                                    NaN
# OrgSize                                                  NaN
# PlatformDesireNextYear                                   NaN
# PlatformWorkedWith                                       NaN
# PurchaseWhat                                             NaN
# Sexuality                                                NaN
# SOAccount                                                NaN
# SOComm                                                   NaN
# SOPartFreq                                               NaN
# SOVisitFreq                                              NaN
# SurveyEase                                               NaN
# SurveyLength                                             NaN
# Trans                                                    NaN
# UndergradMajor                                           NaN
# WebframeDesireNextYear                                   NaN
# WebframeWorkedWith                                       NaN
# WelcomeChange                                            NaN
# WorkWeekHrs                                              NaN
# YearsCode                                                NaN
# YearsCodePro                                             NaN
#
#                                                        38831  \
# MainBranch                    I am a developer by profession
# Hobbyist                                                 Yes
# Age                                                      NaN
# Age1stCode                                               NaN
# CompFreq                                                 NaN
# CompTotal                                                NaN
# ConvertedComp                                            NaN
# Country                                          Netherlands
# CurrencyDesc                                             NaN
# CurrencySymbol                                           NaN
# DatabaseDesireNextYear                                   NaN
# DatabaseWorkedWith                                       NaN
# DevType                                                  NaN
# EdLevel                                                  NaN
# Employment                                Employed full-time
# Ethnicity                                                NaN
# Gender                                                   NaN
# JobFactors                                               NaN
# JobSat                                                   NaN
# JobSeek                                                  NaN
# LanguageDesireNextYear                                   NaN
# LanguageWorkedWith                                       NaN
# MiscTechDesireNextYear                                   NaN
# MiscTechWorkedWith                                       NaN
# NEWCollabToolsDesireNextYear                             NaN
# NEWCollabToolsWorkedWith                                 NaN
# NEWDevOps                                                NaN
# NEWDevOpsImpt                                            NaN
# NEWEdImpt                                                NaN
# NEWJobHunt                                               NaN
# NEWJobHuntResearch                                       NaN
# NEWLearn                                                 NaN
# NEWOffTopic                                              NaN
# NEWOnboardGood                                           NaN
# NEWOtherComms                                            NaN
# NEWOvertime                                              NaN
# NEWPurchaseResearch                                      NaN
# NEWPurpleLink                                            NaN
# NEWSOSites                                               NaN
# NEWStuck                                                 NaN
# OpSys                                                    NaN
# OrgSize                                                  NaN
# PlatformDesireNextYear                                   NaN
# PlatformWorkedWith                                       NaN
# PurchaseWhat                                             NaN
# Sexuality                                                NaN
# SOAccount                                                NaN
# SOComm                                                   NaN
# SOPartFreq                                               NaN
# SOVisitFreq                                              NaN
# SurveyEase                                               NaN
# SurveyLength                                             NaN
# Trans                                                    NaN
# UndergradMajor                                           NaN
# WebframeDesireNextYear                                   NaN
# WebframeWorkedWith                                       NaN
# WelcomeChange                                            NaN
# WorkWeekHrs                                              NaN
# YearsCode                                                NaN
# YearsCodePro                                             NaN
#
#                                                                           7093
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                         NaN
# Age1stCode                                                                  NaN
# CompFreq                                                                    NaN
# CompTotal                                                                   NaN
# ConvertedComp                                                               NaN
# Country                                                               Indonesia
# CurrencyDesc                                                  Indonesian rupiah
# CurrencySymbol                                                              IDR
# DatabaseDesireNextYear                                                      NaN
# DatabaseWorkedWith                                                          NaN
# DevType                                                                     NaN
# EdLevel                                                                     NaN
# Employment                                                   Employed full-time
# Ethnicity                                                                   NaN
# Gender                                                                      NaN
# JobFactors                                                                  NaN
# JobSat                                                                      NaN
# JobSeek                                         I am actively looking for a job
# LanguageDesireNextYear                                                      NaN
# LanguageWorkedWith                                                          NaN
# MiscTechDesireNextYear                                                      NaN
# MiscTechWorkedWith                                                          NaN
# NEWCollabToolsDesireNextYear                                                NaN
# NEWCollabToolsWorkedWith                                                    NaN
# NEWDevOps                                                                   NaN
# NEWDevOpsImpt                                                               NaN
# NEWEdImpt                                                                   NaN
# NEWJobHunt                                                                  NaN
# NEWJobHuntResearch                                                          NaN
# NEWLearn                                                                    NaN
# NEWOffTopic                                                                 NaN
# NEWOnboardGood                                                              NaN
# NEWOtherComms                                                               Yes
# NEWOvertime                                                                 NaN
# NEWPurchaseResearch                                                         NaN
# NEWPurpleLink                                                               NaN
# NEWSOSites                    Stack Overflow (public Q&A for anyone who code...
# NEWStuck                                                                    NaN
# OpSys                                                                       NaN
# OrgSize                                                                     NaN
# PlatformDesireNextYear                                                      NaN
# PlatformWorkedWith                                                          NaN
# PurchaseWhat                                                                NaN
# Sexuality                                                                   NaN
# SOAccount                                                                   Yes
# SOComm                                                          Yes, definitely
# SOPartFreq                                               Multiple times per day
# SOVisitFreq                                              Multiple times per day
# SurveyEase                                                                  NaN
# SurveyLength                                                                NaN
# Trans                                                                       NaN
# UndergradMajor                                                              NaN
# WebframeDesireNextYear                                                      NaN
# WebframeWorkedWith                                                          NaN
# WelcomeChange                                                               NaN
# WorkWeekHrs                                                                 NaN
# YearsCode                                                                   NaN
# YearsCodePro                                                                NaN
#
# [60 rows x 1000 columns]

# %%
survey_df.reset_index(inplace = True) # 先把 index 重置一下，以便后面的学习

# %%
survey_df
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 0         36576                     I am a developer by profession      Yes
# 1         56924  I used to be a developer by profession, but no...      Yes
# 2          3251                        I code primarily as a hobby      Yes
# 3         19890                     I am a developer by profession      Yes
# 4         57451                     I am a developer by profession       No
# ..          ...                                                ...      ...
# 995       45154                     I am a developer by profession      Yes
# 996       59877                     I am a developer by profession      Yes
# 997       64744                     I am a developer by profession      Yes
# 998       38831                     I am a developer by profession      Yes
# 999        7093                     I am a developer by profession      Yes
#
#       Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0    67.0         18  Monthly    35000.0         6600.0  Russian Federation
# 1    63.0         24      NaN        NaN            NaN              Sweden
# 2    62.0         18      NaN        NaN            NaN             Finland
# 3    61.0         21      NaN        NaN            NaN              Canada
# 4    61.0         19   Yearly   600000.0        64737.0              Norway
# ..    ...        ...      ...        ...            ...                 ...
# 995   NaN        NaN      NaN        NaN            NaN             Lebanon
# 996   NaN        NaN      NaN        NaN            NaN         Philippines
# 997   NaN        NaN      NaN        NaN            NaN          Costa Rica
# 998   NaN        NaN      NaN        NaN            NaN         Netherlands
# 999   NaN        NaN      NaN        NaN            NaN           Indonesia
#
#           CurrencyDesc  ...                  SurveyEase  \
# 0        Russian ruble  ...  Neither easy nor difficult
# 1                  NaN  ...                        Easy
# 2                  NaN  ...                        Easy
# 3      Canadian dollar  ...                        Easy
# 4      Norwegian krone  ...                        Easy
# ..                 ...  ...                         ...
# 995                NaN  ...                         NaN
# 996                NaN  ...                         NaN
# 997                NaN  ...                         NaN
# 998                NaN  ...                         NaN
# 999  Indonesian rupiah  ...                         NaN
#
#               SurveyLength Trans  \
# 0    Appropriate in length    No
# 1    Appropriate in length    No
# 2    Appropriate in length    No
# 3    Appropriate in length   NaN
# 4    Appropriate in length    No
# ..                     ...   ...
# 995                    NaN   NaN
# 996                    NaN   NaN
# 997                    NaN   NaN
# 998                    NaN   NaN
# 999                    NaN   NaN
#
#                                         UndergradMajor WebframeDesireNextYear  \
# 0    Another engineering discipline (such as civil,...                    NaN
# 1    A social science (such as anthropology, psycho...                    NaN
# 2    A business discipline (such as accounting, fin...                  Flask
# 3    Another engineering discipline (such as civil,...                    NaN
# 4                                                  NaN                 Vue.js
# ..                                                 ...                    ...
# 995                                                NaN        Angular;Laravel
# 996                                                NaN                    NaN
# 997                                                NaN                    NaN
# 998                                                NaN                    NaN
# 999                                                NaN                    NaN
#
#     WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# 0                  NaN  Somewhat more welcome now than last year        40.0
# 1      jQuery;React.js   Just as welcome now as I felt last year         NaN
# 2                Flask   Just as welcome now as I felt last year         NaN
# 3                  NaN  Somewhat less welcome now than last year        40.0
# 4             React.js   Just as welcome now as I felt last year        38.0
# ..                 ...                                       ...         ...
# 995           React.js                                       NaN         NaN
# 996           React.js                                       NaN         NaN
# 997                NaN                                       NaN         NaN
# 998                NaN                                       NaN         NaN
# 999                NaN                                       NaN         NaN
#
#     YearsCode YearsCodePro
# 0          50           45
# 1          35          NaN
# 2           3          NaN
# 3          39           29
# 4          42           35
# ..        ...          ...
# 995       NaN          NaN
# 996       NaN          NaN
# 997       NaN          NaN
# 998       NaN          NaN
# 999       NaN          NaN
#
# [1000 rows x 61 columns]

# %%
survey_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
survey_df.rename(columns = {'Age': 'user age', 'OrgSize': 'Organization Size'}, inplace = True) # 转换列名（Age => user age，OrgSize => Organization Size)

# %%
survey_df.columns = survey_df.columns.str.replace(' ', '_') # 将列名中的空格换成下划线

# %%
survey_df.columns = [col.lower() for col in survey_df.columns] # 将列名全部变为小写

# %%
survey_df.columns
# Out:
# Index(['respondent', 'mainbranch', 'hobbyist', 'user_age', 'age1stcode',
#        'compfreq', 'comptotal', 'convertedcomp', 'country', 'currencydesc',
#        'currencysymbol', 'databasedesirenextyear', 'databaseworkedwith',
#        'devtype', 'edlevel', 'employment', 'ethnicity', 'gender', 'jobfactors',
#        'jobsat', 'jobseek', 'languagedesirenextyear', 'languageworkedwith',
#        'misctechdesirenextyear', 'misctechworkedwith',
#        'newcollabtoolsdesirenextyear', 'newcollabtoolsworkedwith', 'newdevops',
#        'newdevopsimpt', 'newedimpt', 'newjobhunt', 'newjobhuntresearch',
#        'newlearn', 'newofftopic', 'newonboardgood', 'newothercomms',
#        'newovertime', 'newpurchaseresearch', 'newpurplelink', 'newsosites',
#        'newstuck', 'opsys', 'organization_size', 'platformdesirenextyear',
#        'platformworkedwith', 'purchasewhat', 'sexuality', 'soaccount',
#        'socomm', 'sopartfreq', 'sovisitfreq', 'surveyease', 'surveylength',
#        'trans', 'undergradmajor', 'webframedesirenextyear',
#        'webframeworkedwith', 'welcomechange', 'workweekhrs', 'yearscode',
#        'yearscodepro'],
#       dtype='object')

# %%
survey_df['organization_size'] # 拿到原来OrgSize列的值
# Out:
# 0      1,000 to 4,999 employees
# 1                           NaN
# 2                           NaN
# 3      5,000 to 9,999 employees
# 4      1,000 to 4,999 employees
#                  ...
# 995                         NaN
# 996                         NaN
# 997                         NaN
# 998                         NaN
# 999                         NaN
# Name: organization_size, Length: 1000, dtype: object

# %%
survey_df['jobfactors'].str.lower()
# Out:
# 0      industry that i’d be working in;languages, fra...
# 1                                                    NaN
# 2                                                    NaN
# 3      languages, frameworks, and other technologies ...
# 4      flex time or a flexible schedule;languages, fr...
#                              ...
# 995                                                  NaN
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999                                                  NaN
# Name: jobfactors, Length: 1000, dtype: object

# %%
survey_df['jobfactors'] = survey_df['jobfactors'].str.lower() # 改变jobfactors列上的数据

# %%
survey_df['jobfactors']
# Out:
# 0      industry that i’d be working in;languages, fra...
# 1                                                    NaN
# 2                                                    NaN
# 3      languages, frameworks, and other technologies ...
# 4      flex time or a flexible schedule;languages, fr...
#                              ...
# 995                                                  NaN
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999                                                  NaN
# Name: jobfactors, Length: 1000, dtype: object

# %%
survey_df.loc[2, 'trans'] = 'Yes'

# %%
survey_df.loc[2, 'trans']
# Out:
# 'Yes'

# %%
survey_df.loc[2, ['trans', 'user_age', 'country']]  = ['Yes', 29, 'China'] # 将特定行的三列数据进行改变

# %%
survey_df.loc[2, ['trans', 'user_age', 'country']]
# Out:
# trans         Yes
# user_age       29
# country     China
# Name: 2, dtype: object

# %%
survey_df.loc[survey_df['user_age'] < 18, ['age_group']] = 'young'

# %%
survey_df.loc[~(survey_df['user_age'] < 18), ['age_group']]  = 'adult' # 对于年龄大于等于18的用户，将age_group设为adult

# %%
survey_df
# Out:
#      respondent                                         mainbranch hobbyist  \
# 0         36576                     I am a developer by profession      Yes
# 1         56924  I used to be a developer by profession, but no...      Yes
# 2          3251                        I code primarily as a hobby      Yes
# 3         19890                     I am a developer by profession      Yes
# 4         57451                     I am a developer by profession       No
# ..          ...                                                ...      ...
# 995       45154                     I am a developer by profession      Yes
# 996       59877                     I am a developer by profession      Yes
# 997       64744                     I am a developer by profession      Yes
# 998       38831                     I am a developer by profession      Yes
# 999        7093                     I am a developer by profession      Yes
#
#      user_age age1stcode compfreq  comptotal  convertedcomp  \
# 0        67.0         18  Monthly    35000.0         6600.0
# 1        63.0         24      NaN        NaN            NaN
# 2        29.0         18      NaN        NaN            NaN
# 3        61.0         21      NaN        NaN            NaN
# 4        61.0         19   Yearly   600000.0        64737.0
# ..        ...        ...      ...        ...            ...
# 995       NaN        NaN      NaN        NaN            NaN
# 996       NaN        NaN      NaN        NaN            NaN
# 997       NaN        NaN      NaN        NaN            NaN
# 998       NaN        NaN      NaN        NaN            NaN
# 999       NaN        NaN      NaN        NaN            NaN
#
#                 country       currencydesc  ...           surveylength trans  \
# 0    Russian Federation      Russian ruble  ...  Appropriate in length    No
# 1                Sweden                NaN  ...  Appropriate in length    No
# 2                 China                NaN  ...  Appropriate in length   Yes
# 3                Canada    Canadian dollar  ...  Appropriate in length   NaN
# 4                Norway    Norwegian krone  ...  Appropriate in length    No
# ..                  ...                ...  ...                    ...   ...
# 995             Lebanon                NaN  ...                    NaN   NaN
# 996         Philippines                NaN  ...                    NaN   NaN
# 997          Costa Rica                NaN  ...                    NaN   NaN
# 998         Netherlands                NaN  ...                    NaN   NaN
# 999           Indonesia  Indonesian rupiah  ...                    NaN   NaN
#
#                                         undergradmajor webframedesirenextyear  \
# 0    Another engineering discipline (such as civil,...                    NaN
# 1    A social science (such as anthropology, psycho...                    NaN
# 2    A business discipline (such as accounting, fin...                  Flask
# 3    Another engineering discipline (such as civil,...                    NaN
# 4                                                  NaN                 Vue.js
# ..                                                 ...                    ...
# 995                                                NaN        Angular;Laravel
# 996                                                NaN                    NaN
# 997                                                NaN                    NaN
# 998                                                NaN                    NaN
# 999                                                NaN                    NaN
#
#     webframeworkedwith                             welcomechange workweekhrs  \
# 0                  NaN  Somewhat more welcome now than last year        40.0
# 1      jQuery;React.js   Just as welcome now as I felt last year         NaN
# 2                Flask   Just as welcome now as I felt last year         NaN
# 3                  NaN  Somewhat less welcome now than last year        40.0
# 4             React.js   Just as welcome now as I felt last year        38.0
# ..                 ...                                       ...         ...
# 995           React.js                                       NaN         NaN
# 996           React.js                                       NaN         NaN
# 997                NaN                                       NaN         NaN
# 998                NaN                                       NaN         NaN
# 999                NaN                                       NaN         NaN
#
#     yearscode yearscodepro age_group
# 0          50           45     adult
# 1          35          NaN     adult
# 2           3          NaN     adult
# 3          39           29     adult
# 4          42           35     adult
# ..        ...          ...       ...
# 995       NaN          NaN     adult
# 996       NaN          NaN     adult
# 997       NaN          NaN     adult
# 998       NaN          NaN     adult
# 999       NaN          NaN     adult
#
# [1000 rows x 62 columns]

# %%
survey_df['gender'] + survey_df['sexuality'] + survey_df['trans'] # 将性别相关的列合在一起
# Out:
# 0       ManStraight / HeterosexualNo
# 1       ManStraight / HeterosexualNo
# 2      ManStraight / HeterosexualYes
# 3                                NaN
# 4       ManStraight / HeterosexualNo
#                    ...
# 995                              NaN
# 996                              NaN
# 997                              NaN
# 998                              NaN
# 999                              NaN
# Length: 1000, dtype: object

# %%
survey_df['gen_col'] = survey_df['gender'] + survey_df['sexuality'] + survey_df['trans'] # 将合起来的值写入gen_col列

# %%
survey_df['gen_col']
# Out:
# 0       ManStraight / HeterosexualNo
# 1       ManStraight / HeterosexualNo
# 2      ManStraight / HeterosexualYes
# 3                                NaN
# 4       ManStraight / HeterosexualNo
#                    ...
# 995                              NaN
# 996                              NaN
# 997                              NaN
# 998                              NaN
# 999                              NaN
# Name: gen_col, Length: 1000, dtype: object

# %%
survey_df['job_factors'] =  survey_df['jobfactors'].str.split(';')

# %%
survey_df['job_factors']
# Out:
# 0      [industry that i’d be working in, languages, f...
# 1                                                    NaN
# 2                                                    NaN
# 3      [languages, frameworks, and other technologies...
# 4      [flex time or a flexible schedule, languages, ...
#                              ...
# 995                                                  NaN
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999                                                  NaN
# Name: job_factors, Length: 1000, dtype: object

# %%
survey_df[['job_fac1', 'job_fac2', 'job_fac3']] = survey_df['jobfactors'].str.split(';', expand = True)

# %%
survey_df[['job_fac1', 'job_fac2', 'job_fac3']]
# Out:
#                                               job_fac1  \
# 0                      industry that i’d be working in
# 1                                                  NaN
# 2                                                  NaN
# 3    languages, frameworks, and other technologies ...
# 4                     flex time or a flexible schedule
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac2  \
# 0    languages, frameworks, and other technologies ...
# 1                                                  NaN
# 2                                                  NaN
# 3        specific department or team i’d be working on
# 4    languages, frameworks, and other technologies ...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                        job_fac3
# 0                           remote work options
# 1                                           NaN
# 2                                           NaN
# 3    opportunities for professional development
# 4                           remote work options
# ..                                          ...
# 995                                         NaN
# 996                                         NaN
# 997                                         NaN
# 998                                         NaN
# 999                                         NaN
#
# [1000 rows x 3 columns]

# %%
survey_df.append({'user_age': 21}, ignore_index = True) # 加上 ignore_index 就能顺利添加
# Out:
#       respondent                                         mainbranch hobbyist  \
# 0        36576.0                     I am a developer by profession      Yes
# 1        56924.0  I used to be a developer by profession, but no...      Yes
# 2         3251.0                        I code primarily as a hobby      Yes
# 3        19890.0                     I am a developer by profession      Yes
# 4        57451.0                     I am a developer by profession       No
# ...          ...                                                ...      ...
# 996      59877.0                     I am a developer by profession      Yes
# 997      64744.0                     I am a developer by profession      Yes
# 998      38831.0                     I am a developer by profession      Yes
# 999       7093.0                     I am a developer by profession      Yes
# 1000         NaN                                                NaN      NaN
#
#       user_age age1stcode compfreq  comptotal  convertedcomp  \
# 0         67.0         18  Monthly    35000.0         6600.0
# 1         63.0         24      NaN        NaN            NaN
# 2         29.0         18      NaN        NaN            NaN
# 3         61.0         21      NaN        NaN            NaN
# 4         61.0         19   Yearly   600000.0        64737.0
# ...        ...        ...      ...        ...            ...
# 996        NaN        NaN      NaN        NaN            NaN
# 997        NaN        NaN      NaN        NaN            NaN
# 998        NaN        NaN      NaN        NaN            NaN
# 999        NaN        NaN      NaN        NaN            NaN
# 1000      21.0        NaN      NaN        NaN            NaN
#
#                  country       currencydesc  ...  \
# 0     Russian Federation      Russian ruble  ...
# 1                 Sweden                NaN  ...
# 2                  China                NaN  ...
# 3                 Canada    Canadian dollar  ...
# 4                 Norway    Norwegian krone  ...
# ...                  ...                ...  ...
# 996          Philippines                NaN  ...
# 997           Costa Rica                NaN  ...
# 998          Netherlands                NaN  ...
# 999            Indonesia  Indonesian rupiah  ...
# 1000                 NaN                NaN  ...
#
#                                  welcomechange workweekhrs yearscode  \
# 0     Somewhat more welcome now than last year        40.0        50
# 1      Just as welcome now as I felt last year         NaN        35
# 2      Just as welcome now as I felt last year         NaN         3
# 3     Somewhat less welcome now than last year        40.0        39
# 4      Just as welcome now as I felt last year        38.0        42
# ...                                        ...         ...       ...
# 996                                        NaN         NaN       NaN
# 997                                        NaN         NaN       NaN
# 998                                        NaN         NaN       NaN
# 999                                        NaN         NaN       NaN
# 1000                                       NaN         NaN       NaN
#
#      yearscodepro age_group                        gen_col  \
# 0              45     adult   ManStraight / HeterosexualNo
# 1             NaN     adult   ManStraight / HeterosexualNo
# 2             NaN     adult  ManStraight / HeterosexualYes
# 3              29     adult                            NaN
# 4              35     adult   ManStraight / HeterosexualNo
# ...           ...       ...                            ...
# 996           NaN     adult                            NaN
# 997           NaN     adult                            NaN
# 998           NaN     adult                            NaN
# 999           NaN     adult                            NaN
# 1000          NaN       NaN                            NaN
#
#                                             job_factors  \
# 0     [industry that i’d be working in, languages, f...
# 1                                                   NaN
# 2                                                   NaN
# 3     [languages, frameworks, and other technologies...
# 4     [flex time or a flexible schedule, languages, ...
# ...                                                 ...
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
#
#                                                job_fac1  \
# 0                       industry that i’d be working in
# 1                                                   NaN
# 2                                                   NaN
# 3     languages, frameworks, and other technologies ...
# 4                      flex time or a flexible schedule
# ...                                                 ...
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
#
#                                                job_fac2  \
# 0     languages, frameworks, and other technologies ...
# 1                                                   NaN
# 2                                                   NaN
# 3         specific department or team i’d be working on
# 4     languages, frameworks, and other technologies ...
# ...                                                 ...
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
#
#                                         job_fac3
# 0                            remote work options
# 1                                            NaN
# 2                                            NaN
# 3     opportunities for professional development
# 4                            remote work options
# ...                                          ...
# 996                                          NaN
# 997                                          NaN
# 998                                          NaN
# 999                                          NaN
# 1000                                         NaN
#
# [1001 rows x 67 columns]

# %%
new_survey = {
   'user_age': 25,
   'country': 'China',
   'age1stcode': '24'
}
new_survey_df = pd.DataFrame(new_survey, index=[0])

# %%
new_survey_df
# Out:
#    user_age country age1stcode
# 0        25   China         24

# %%
survey_df.append(new_survey_df, ignore_index = True, sort = False)
# Out:
#       respondent                                         mainbranch hobbyist  \
# 0        36576.0                     I am a developer by profession      Yes
# 1        56924.0  I used to be a developer by profession, but no...      Yes
# 2         3251.0                        I code primarily as a hobby      Yes
# 3        19890.0                     I am a developer by profession      Yes
# 4        57451.0                     I am a developer by profession       No
# ...          ...                                                ...      ...
# 996      59877.0                     I am a developer by profession      Yes
# 997      64744.0                     I am a developer by profession      Yes
# 998      38831.0                     I am a developer by profession      Yes
# 999       7093.0                     I am a developer by profession      Yes
# 1000         NaN                                                NaN      NaN
#
#       user_age age1stcode compfreq  comptotal  convertedcomp  \
# 0         67.0         18  Monthly    35000.0         6600.0
# 1         63.0         24      NaN        NaN            NaN
# 2         29.0         18      NaN        NaN            NaN
# 3         61.0         21      NaN        NaN            NaN
# 4         61.0         19   Yearly   600000.0        64737.0
# ...        ...        ...      ...        ...            ...
# 996        NaN        NaN      NaN        NaN            NaN
# 997        NaN        NaN      NaN        NaN            NaN
# 998        NaN        NaN      NaN        NaN            NaN
# 999        NaN        NaN      NaN        NaN            NaN
# 1000      25.0         24      NaN        NaN            NaN
#
#                  country       currencydesc  ...  \
# 0     Russian Federation      Russian ruble  ...
# 1                 Sweden                NaN  ...
# 2                  China                NaN  ...
# 3                 Canada    Canadian dollar  ...
# 4                 Norway    Norwegian krone  ...
# ...                  ...                ...  ...
# 996          Philippines                NaN  ...
# 997           Costa Rica                NaN  ...
# 998          Netherlands                NaN  ...
# 999            Indonesia  Indonesian rupiah  ...
# 1000               China                NaN  ...
#
#                                  welcomechange workweekhrs yearscode  \
# 0     Somewhat more welcome now than last year        40.0        50
# 1      Just as welcome now as I felt last year         NaN        35
# 2      Just as welcome now as I felt last year         NaN         3
# 3     Somewhat less welcome now than last year        40.0        39
# 4      Just as welcome now as I felt last year        38.0        42
# ...                                        ...         ...       ...
# 996                                        NaN         NaN       NaN
# 997                                        NaN         NaN       NaN
# 998                                        NaN         NaN       NaN
# 999                                        NaN         NaN       NaN
# 1000                                       NaN         NaN       NaN
#
#      yearscodepro age_group                        gen_col  \
# 0              45     adult   ManStraight / HeterosexualNo
# 1             NaN     adult   ManStraight / HeterosexualNo
# 2             NaN     adult  ManStraight / HeterosexualYes
# 3              29     adult                            NaN
# 4              35     adult   ManStraight / HeterosexualNo
# ...           ...       ...                            ...
# 996           NaN     adult                            NaN
# 997           NaN     adult                            NaN
# 998           NaN     adult                            NaN
# 999           NaN     adult                            NaN
# 1000          NaN       NaN                            NaN
#
#                                             job_factors  \
# 0     [industry that i’d be working in, languages, f...
# 1                                                   NaN
# 2                                                   NaN
# 3     [languages, frameworks, and other technologies...
# 4     [flex time or a flexible schedule, languages, ...
# ...                                                 ...
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
#
#                                                job_fac1  \
# 0                       industry that i’d be working in
# 1                                                   NaN
# 2                                                   NaN
# 3     languages, frameworks, and other technologies ...
# 4                      flex time or a flexible schedule
# ...                                                 ...
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
#
#                                                job_fac2  \
# 0     languages, frameworks, and other technologies ...
# 1                                                   NaN
# 2                                                   NaN
# 3         specific department or team i’d be working on
# 4     languages, frameworks, and other technologies ...
# ...                                                 ...
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
#
#                                         job_fac3
# 0                            remote work options
# 1                                            NaN
# 2                                            NaN
# 3     opportunities for professional development
# 4                            remote work options
# ...                                          ...
# 996                                          NaN
# 997                                          NaN
# 998                                          NaN
# 999                                          NaN
# 1000                                         NaN
#
# [1001 rows x 67 columns]

# %%
survey_df.drop(columns = ['organization_size', 'soaccount'], inplace = True) # 删除 organization_size 和 soaccount 这两列数据

# %%
survey_df
# Out:
#      respondent                                         mainbranch hobbyist  \
# 0         36576                     I am a developer by profession      Yes
# 1         56924  I used to be a developer by profession, but no...      Yes
# 2          3251                        I code primarily as a hobby      Yes
# 3         19890                     I am a developer by profession      Yes
# 4         57451                     I am a developer by profession       No
# ..          ...                                                ...      ...
# 995       45154                     I am a developer by profession      Yes
# 996       59877                     I am a developer by profession      Yes
# 997       64744                     I am a developer by profession      Yes
# 998       38831                     I am a developer by profession      Yes
# 999        7093                     I am a developer by profession      Yes
#
#      user_age age1stcode compfreq  comptotal  convertedcomp  \
# 0        67.0         18  Monthly    35000.0         6600.0
# 1        63.0         24      NaN        NaN            NaN
# 2        29.0         18      NaN        NaN            NaN
# 3        61.0         21      NaN        NaN            NaN
# 4        61.0         19   Yearly   600000.0        64737.0
# ..        ...        ...      ...        ...            ...
# 995       NaN        NaN      NaN        NaN            NaN
# 996       NaN        NaN      NaN        NaN            NaN
# 997       NaN        NaN      NaN        NaN            NaN
# 998       NaN        NaN      NaN        NaN            NaN
# 999       NaN        NaN      NaN        NaN            NaN
#
#                 country       currencydesc  ...  \
# 0    Russian Federation      Russian ruble  ...
# 1                Sweden                NaN  ...
# 2                 China                NaN  ...
# 3                Canada    Canadian dollar  ...
# 4                Norway    Norwegian krone  ...
# ..                  ...                ...  ...
# 995             Lebanon                NaN  ...
# 996         Philippines                NaN  ...
# 997          Costa Rica                NaN  ...
# 998         Netherlands                NaN  ...
# 999           Indonesia  Indonesian rupiah  ...
#
#                                 welcomechange workweekhrs yearscode  \
# 0    Somewhat more welcome now than last year        40.0        50
# 1     Just as welcome now as I felt last year         NaN        35
# 2     Just as welcome now as I felt last year         NaN         3
# 3    Somewhat less welcome now than last year        40.0        39
# 4     Just as welcome now as I felt last year        38.0        42
# ..                                        ...         ...       ...
# 995                                       NaN         NaN       NaN
# 996                                       NaN         NaN       NaN
# 997                                       NaN         NaN       NaN
# 998                                       NaN         NaN       NaN
# 999                                       NaN         NaN       NaN
#
#     yearscodepro age_group                        gen_col  \
# 0             45     adult   ManStraight / HeterosexualNo
# 1            NaN     adult   ManStraight / HeterosexualNo
# 2            NaN     adult  ManStraight / HeterosexualYes
# 3             29     adult                            NaN
# 4             35     adult   ManStraight / HeterosexualNo
# ..           ...       ...                            ...
# 995          NaN     adult                            NaN
# 996          NaN     adult                            NaN
# 997          NaN     adult                            NaN
# 998          NaN     adult                            NaN
# 999          NaN     adult                            NaN
#
#                                            job_factors  \
# 0    [industry that i’d be working in, languages, f...
# 1                                                  NaN
# 2                                                  NaN
# 3    [languages, frameworks, and other technologies...
# 4    [flex time or a flexible schedule, languages, ...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac1  \
# 0                      industry that i’d be working in
# 1                                                  NaN
# 2                                                  NaN
# 3    languages, frameworks, and other technologies ...
# 4                     flex time or a flexible schedule
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac2  \
# 0    languages, frameworks, and other technologies ...
# 1                                                  NaN
# 2                                                  NaN
# 3        specific department or team i’d be working on
# 4    languages, frameworks, and other technologies ...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                        job_fac3
# 0                           remote work options
# 1                                           NaN
# 2                                           NaN
# 3    opportunities for professional development
# 4                           remote work options
# ..                                          ...
# 995                                         NaN
# 996                                         NaN
# 997                                         NaN
# 998                                         NaN
# 999                                         NaN
#
# [1000 rows x 65 columns]

# %%
survey_df.drop(index = 4) # 删除 index 为 4 的数据
# Out:
#      respondent                                         mainbranch hobbyist  \
# 0         36576                     I am a developer by profession      Yes
# 1         56924  I used to be a developer by profession, but no...      Yes
# 2          3251                        I code primarily as a hobby      Yes
# 3         19890                     I am a developer by profession      Yes
# 5         43830                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 995       45154                     I am a developer by profession      Yes
# 996       59877                     I am a developer by profession      Yes
# 997       64744                     I am a developer by profession      Yes
# 998       38831                     I am a developer by profession      Yes
# 999        7093                     I am a developer by profession      Yes
#
#      user_age age1stcode compfreq  comptotal  convertedcomp  \
# 0        67.0         18  Monthly    35000.0         6600.0
# 1        63.0         24      NaN        NaN            NaN
# 2        29.0         18      NaN        NaN            NaN
# 3        61.0         21      NaN        NaN            NaN
# 5        61.0         18   Yearly   125000.0       125000.0
# ..        ...        ...      ...        ...            ...
# 995       NaN        NaN      NaN        NaN            NaN
# 996       NaN        NaN      NaN        NaN            NaN
# 997       NaN        NaN      NaN        NaN            NaN
# 998       NaN        NaN      NaN        NaN            NaN
# 999       NaN        NaN      NaN        NaN            NaN
#
#                 country          currencydesc  ...  \
# 0    Russian Federation         Russian ruble  ...
# 1                Sweden                   NaN  ...
# 2                 China                   NaN  ...
# 3                Canada       Canadian dollar  ...
# 5         United States  United States dollar  ...
# ..                  ...                   ...  ...
# 995             Lebanon                   NaN  ...
# 996         Philippines                   NaN  ...
# 997          Costa Rica                   NaN  ...
# 998         Netherlands                   NaN  ...
# 999           Indonesia     Indonesian rupiah  ...
#
#                                 welcomechange workweekhrs yearscode  \
# 0    Somewhat more welcome now than last year        40.0        50
# 1     Just as welcome now as I felt last year         NaN        35
# 2     Just as welcome now as I felt last year         NaN         3
# 3    Somewhat less welcome now than last year        40.0        39
# 5     Just as welcome now as I felt last year        40.0        43
# ..                                        ...         ...       ...
# 995                                       NaN         NaN       NaN
# 996                                       NaN         NaN       NaN
# 997                                       NaN         NaN       NaN
# 998                                       NaN         NaN       NaN
# 999                                       NaN         NaN       NaN
#
#     yearscodepro age_group                        gen_col  \
# 0             45     adult   ManStraight / HeterosexualNo
# 1            NaN     adult   ManStraight / HeterosexualNo
# 2            NaN     adult  ManStraight / HeterosexualYes
# 3             29     adult                            NaN
# 5             37     adult   ManStraight / HeterosexualNo
# ..           ...       ...                            ...
# 995          NaN     adult                            NaN
# 996          NaN     adult                            NaN
# 997          NaN     adult                            NaN
# 998          NaN     adult                            NaN
# 999          NaN     adult                            NaN
#
#                                            job_factors  \
# 0    [industry that i’d be working in, languages, f...
# 1                                                  NaN
# 2                                                  NaN
# 3    [languages, frameworks, and other technologies...
# 5    [specific department or team i’d be working on...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac1  \
# 0                      industry that i’d be working in
# 1                                                  NaN
# 2                                                  NaN
# 3    languages, frameworks, and other technologies ...
# 5        specific department or team i’d be working on
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac2  \
# 0    languages, frameworks, and other technologies ...
# 1                                                  NaN
# 2                                                  NaN
# 3        specific department or team i’d be working on
# 5                                  remote work options
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                        job_fac3
# 0                           remote work options
# 1                                           NaN
# 2                                           NaN
# 3    opportunities for professional development
# 5    opportunities for professional development
# ..                                          ...
# 995                                         NaN
# 996                                         NaN
# 997                                         NaN
# 998                                         NaN
# 999                                         NaN
#
# [999 rows x 65 columns]

# %%
age_filter = survey_df['user_age'] < 50

# %%
survey_df.drop(index = survey_df[age_filter].index) # 删除特定满足特定条件（年龄大于50）的数据
# Out:
#      respondent                                         mainbranch hobbyist  \
# 0         36576                     I am a developer by profession      Yes
# 1         56924  I used to be a developer by profession, but no...      Yes
# 3         19890                     I am a developer by profession      Yes
# 4         57451                     I am a developer by profession       No
# 5         43830                     I am a developer by profession      Yes
# ..          ...                                                ...      ...
# 995       45154                     I am a developer by profession      Yes
# 996       59877                     I am a developer by profession      Yes
# 997       64744                     I am a developer by profession      Yes
# 998       38831                     I am a developer by profession      Yes
# 999        7093                     I am a developer by profession      Yes
#
#      user_age age1stcode compfreq  comptotal  convertedcomp  \
# 0        67.0         18  Monthly    35000.0         6600.0
# 1        63.0         24      NaN        NaN            NaN
# 3        61.0         21      NaN        NaN            NaN
# 4        61.0         19   Yearly   600000.0        64737.0
# 5        61.0         18   Yearly   125000.0       125000.0
# ..        ...        ...      ...        ...            ...
# 995       NaN        NaN      NaN        NaN            NaN
# 996       NaN        NaN      NaN        NaN            NaN
# 997       NaN        NaN      NaN        NaN            NaN
# 998       NaN        NaN      NaN        NaN            NaN
# 999       NaN        NaN      NaN        NaN            NaN
#
#                 country          currencydesc  ...  \
# 0    Russian Federation         Russian ruble  ...
# 1                Sweden                   NaN  ...
# 3                Canada       Canadian dollar  ...
# 4                Norway       Norwegian krone  ...
# 5         United States  United States dollar  ...
# ..                  ...                   ...  ...
# 995             Lebanon                   NaN  ...
# 996         Philippines                   NaN  ...
# 997          Costa Rica                   NaN  ...
# 998         Netherlands                   NaN  ...
# 999           Indonesia     Indonesian rupiah  ...
#
#                                 welcomechange workweekhrs yearscode  \
# 0    Somewhat more welcome now than last year        40.0        50
# 1     Just as welcome now as I felt last year         NaN        35
# 3    Somewhat less welcome now than last year        40.0        39
# 4     Just as welcome now as I felt last year        38.0        42
# 5     Just as welcome now as I felt last year        40.0        43
# ..                                        ...         ...       ...
# 995                                       NaN         NaN       NaN
# 996                                       NaN         NaN       NaN
# 997                                       NaN         NaN       NaN
# 998                                       NaN         NaN       NaN
# 999                                       NaN         NaN       NaN
#
#     yearscodepro age_group                       gen_col  \
# 0             45     adult  ManStraight / HeterosexualNo
# 1            NaN     adult  ManStraight / HeterosexualNo
# 3             29     adult                           NaN
# 4             35     adult  ManStraight / HeterosexualNo
# 5             37     adult  ManStraight / HeterosexualNo
# ..           ...       ...                           ...
# 995          NaN     adult                           NaN
# 996          NaN     adult                           NaN
# 997          NaN     adult                           NaN
# 998          NaN     adult                           NaN
# 999          NaN     adult                           NaN
#
#                                            job_factors  \
# 0    [industry that i’d be working in, languages, f...
# 1                                                  NaN
# 3    [languages, frameworks, and other technologies...
# 4    [flex time or a flexible schedule, languages, ...
# 5    [specific department or team i’d be working on...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac1  \
# 0                      industry that i’d be working in
# 1                                                  NaN
# 3    languages, frameworks, and other technologies ...
# 4                     flex time or a flexible schedule
# 5        specific department or team i’d be working on
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                               job_fac2  \
# 0    languages, frameworks, and other technologies ...
# 1                                                  NaN
# 3        specific department or team i’d be working on
# 4    languages, frameworks, and other technologies ...
# 5                                  remote work options
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                        job_fac3
# 0                           remote work options
# 1                                           NaN
# 3    opportunities for professional development
# 4                           remote work options
# 5    opportunities for professional development
# ..                                          ...
# 995                                         NaN
# 996                                         NaN
# 997                                         NaN
# 998                                         NaN
# 999                                         NaN
#
# [336 rows x 65 columns]

# %%
# apply, map, applymap, replace

# %%
dtypes = survey_df.dtypes
str_cols = [col_name for col_name in dtypes.index if dtypes[col_name] == 'object']
survey_df[str_cols] = survey_df[str_cols].astype(str)

# %%
survey_df['hobbyist']
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 995    Yes
# 996    Yes
# 997    Yes
# 998    Yes
# 999    Yes
# Name: hobbyist, Length: 1000, dtype: object

# %%
survey_df['hobbyist'].apply(len) # 查看这列数据的字符长度
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      2
#       ..
# 995    3
# 996    3
# 997    3
# 998    3
# 999    3
# Name: hobbyist, Length: 1000, dtype: int64

# %%
def upper_case(col_value):
     return col_value.upper()

# %%
survey_df['hobbyist'] = survey_df['hobbyist'].apply(upper_case) # 将此列的数据全部变成大写

# %%
survey_df['hobbyist'] = survey_df['hobbyist'].apply(lambda x: x.lower()) # 使用匿名函数将此列数据全部变成小写

# %%
survey_df['hobbyist']
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 995    yes
# 996    yes
# 997    yes
# 998    yes
# 999    yes
# Name: hobbyist, Length: 1000, dtype: object

# %%
survey_df.apply(len) # 查看每列的长度（有多少行）
# Out:
# respondent     1000
# mainbranch     1000
# hobbyist       1000
# user_age       1000
# age1stcode     1000
#                ...
# gen_col        1000
# job_factors    1000
# job_fac1       1000
# job_fac2       1000
# job_fac3       1000
# Length: 65, dtype: int64

# %%
survey_df.apply(len, axis = 'columns') # 查看每行的长度（有多少列）
# Out:
# 0      65
# 1      65
# 2      65
# 3      65
# 4      65
#        ..
# 995    65
# 996    65
# 997    65
# 998    65
# 999    65
# Length: 1000, dtype: int64

# %%
survey_df.apply(lambda x: x.min()) # 其中 x 代表一个Series，此行代码也能拿到每列中最小的数值
# Out:
# respondent                                                    59
# mainbranch                        I am a developer by profession
# hobbyist                                                     nan
# user_age                                                      13
# age1stcode                                                    10
#                                      ...
# gen_col        Man;Non-binary, genderqueer, or gender non-con...
# job_factors    ['diversity of the company or organization', '...
# job_fac1                diversity of the company or organization
# job_fac2                diversity of the company or organization
# job_fac3                                     family friendliness
# Length: 65, dtype: object

# %%
survey_df['hobbyist']
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 995    yes
# 996    yes
# 997    yes
# 998    yes
# 999    yes
# Name: hobbyist, Length: 1000, dtype: object

# %%
map_dict = {'yes': 'True', 'no': 'False'}

# %%
survey_df['hobbyist'].map(map_dict) # 将yes转为True，no转为False，不match的变成NaN
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: hobbyist, Length: 1000, dtype: object

# %%
str_cols
# Out:
# ['mainbranch',
#  'hobbyist',
#  'age1stcode',
#  'compfreq',
#  'country',
#  'currencydesc',
#  'currencysymbol',
#  'databasedesirenextyear',
#  'databaseworkedwith',
#  'devtype',
#  'edlevel',
#  'employment',
#  'ethnicity',
#  'gender',
#  'jobfactors',
#  'jobsat',
#  'jobseek',
#  'languagedesirenextyear',
#  'languageworkedwith',
#  'misctechdesirenextyear',
#  'misctechworkedwith',
#  'newcollabtoolsdesirenextyear',
#  'newcollabtoolsworkedwith',
#  'newdevops',
#  'newdevopsimpt',
#  'newedimpt',
#  'newjobhunt',
#  'newjobhuntresearch',
#  'newlearn',
#  'newofftopic',
#  'newonboardgood',
#  'newothercomms',
#  'newovertime',
#  'newpurchaseresearch',
#  'newpurplelink',
#  'newsosites',
#  'newstuck',
#  'opsys',
#  'platformdesirenextyear',
#  'platformworkedwith',
#  'purchasewhat',
#  'sexuality',
#  'socomm',
#  'sopartfreq',
#  'sovisitfreq',
#  'surveyease',
#  'surveylength',
#  'trans',
#  'undergradmajor',
#  'webframedesirenextyear',
#  'webframeworkedwith',
#  'welcomechange',
#  'yearscode',
#  'yearscodepro',
#  'age_group',
#  'gen_col',
#  'job_factors',
#  'job_fac1',
#  'job_fac2',
#  'job_fac3']

# %%
survey_df[str_cols].applymap(len) # 针对于每个元素，对每个str数据类型的数据使用len函数
# Out:
#      mainbranch  hobbyist  age1stcode  compfreq  country  currencydesc  \
# 0            30         3           2         7       18            13
# 1            56         3           2         3        6             3
# 2            27         3           2         3        5             3
# 3            30         3           2         3        6            15
# 4            30         2           2         6        6            15
# ..          ...       ...         ...       ...      ...           ...
# 995          30         3           3         3        7             3
# 996          30         3           3         3       11             3
# 997          30         3           3         3       10             3
# 998          30         3           3         3       11             3
# 999          30         3           3         3        9            17
#
#      currencysymbol  databasedesirenextyear  databaseworkedwith  devtype  ...  \
# 0                 3                       6                   6      109  ...
# 1                 3                      10                  27        3  ...
# 2                 3                      44                  44        3  ...
# 3                 3                       3                  20       54  ...
# 4                 3                       8                  37       36  ...
# ..              ...                     ...                 ...      ...  ...
# 995               3                       7                  50        3  ...
# 996               3                       3                  27        3  ...
# 997               3                       3                   3        3  ...
# 998               3                       3                   3        3  ...
# 999               3                       3                   3        3  ...
#
#      webframeworkedwith  welcomechange  yearscode  yearscodepro  age_group  \
# 0                     3             40          2             2          5
# 1                    15             39          2             3          5
# 2                     5             39          1             3          5
# 3                     3             40          2             2          5
# 4                     8             39          2             2          5
# ..                  ...            ...        ...           ...        ...
# 995                   8              3          3             3          5
# 996                   8              3          3             3          5
# 997                   3              3          3             3          5
# 998                   3              3          3             3          5
# 999                   3              3          3             3          5
#
#      gen_col  job_factors  job_fac1  job_fac2  job_fac3
# 0         28          127        31        65        19
# 1         28            3         3         3         3
# 2         29            3         3         3         3
# 3          3          164        65        45        42
# 4         28          128        32        65        19
# ..       ...          ...       ...       ...       ...
# 995        3            3         3         3         3
# 996        3            3         3         3         3
# 997        3            3         3         3         3
# 998        3            3         3         3         3
# 999        3            3         3         3         3
#
# [1000 rows x 60 columns]

# %%
survey_df[str_cols].applymap(str.lower) # 对每个str数据类型的数据使用lower函数
# Out:
#                                             mainbranch hobbyist age1stcode  \
# 0                       i am a developer by profession      yes         18
# 1    i used to be a developer by profession, but no...      yes         24
# 2                          i code primarily as a hobby      yes         18
# 3                       i am a developer by profession      yes         21
# 4                       i am a developer by profession       no         19
# ..                                                 ...      ...        ...
# 995                     i am a developer by profession      yes        nan
# 996                     i am a developer by profession      yes        nan
# 997                     i am a developer by profession      yes        nan
# 998                     i am a developer by profession      yes        nan
# 999                     i am a developer by profession      yes        nan
#
#     compfreq             country       currencydesc currencysymbol  \
# 0    monthly  russian federation      russian ruble            rub
# 1        nan              sweden                nan            nan
# 2        nan               china                nan            nan
# 3        nan              canada    canadian dollar            cad
# 4     yearly              norway    norwegian krone            nok
# ..       ...                 ...                ...            ...
# 995      nan             lebanon                nan            nan
# 996      nan         philippines                nan            nan
# 997      nan          costa rica                nan            nan
# 998      nan         netherlands                nan            nan
# 999      nan           indonesia  indonesian rupiah            idr
#
#                            databasedesirenextyear  \
# 0                                          sqlite
# 1                                      postgresql
# 2    microsoft sql server;mysql;postgresql;sqlite
# 3                                             nan
# 4                                        firebase
# ..                                            ...
# 995                                       mongodb
# 996                                           nan
# 997                                           nan
# 998                                           nan
# 999                                           nan
#
#                                     databaseworkedwith  \
# 0                                               sqlite
# 1                          mariadb;mysql;oracle;sqlite
# 2         microsoft sql server;mysql;postgresql;sqlite
# 3                                 microsoft sql server
# 4                microsoft sql server;mysql;postgresql
# ..                                                 ...
# 995  firebase;mariadb;microsoft sql server;mysql;sq...
# 996                        firebase;mongodb;postgresql
# 997                                                nan
# 998                                                nan
# 999                                                nan
#
#                                                devtype  ...  \
# 0    developer, back-end;developer, desktop or ente...  ...
# 1                                                  nan  ...
# 2                                                  nan  ...
# 3    designer;developer, desktop or enterprise appl...  ...
# 4                 developer, front-end;product manager  ...
# ..                                                 ...  ...
# 995                                                nan  ...
# 996                                                nan  ...
# 997                                                nan  ...
# 998                                                nan  ...
# 999                                                nan  ...
#
#     webframeworkedwith                             welcomechange yearscode  \
# 0                  nan  somewhat more welcome now than last year        50
# 1      jquery;react.js   just as welcome now as i felt last year        35
# 2                flask   just as welcome now as i felt last year         3
# 3                  nan  somewhat less welcome now than last year        39
# 4             react.js   just as welcome now as i felt last year        42
# ..                 ...                                       ...       ...
# 995           react.js                                       nan       nan
# 996           react.js                                       nan       nan
# 997                nan                                       nan       nan
# 998                nan                                       nan       nan
# 999                nan                                       nan       nan
#
#     yearscodepro age_group                        gen_col  \
# 0             45     adult   manstraight / heterosexualno
# 1            nan     adult   manstraight / heterosexualno
# 2            nan     adult  manstraight / heterosexualyes
# 3             29     adult                            nan
# 4             35     adult   manstraight / heterosexualno
# ..           ...       ...                            ...
# 995          nan     adult                            nan
# 996          nan     adult                            nan
# 997          nan     adult                            nan
# 998          nan     adult                            nan
# 999          nan     adult                            nan
#
#                                            job_factors  \
# 0    ['industry that i’d be working in', 'languages...
# 1                                                  nan
# 2                                                  nan
# 3    ['languages, frameworks, and other technologie...
# 4    ['flex time or a flexible schedule', 'language...
# ..                                                 ...
# 995                                                nan
# 996                                                nan
# 997                                                nan
# 998                                                nan
# 999                                                nan
#
#                                               job_fac1  \
# 0                      industry that i’d be working in
# 1                                                  nan
# 2                                                  nan
# 3    languages, frameworks, and other technologies ...
# 4                     flex time or a flexible schedule
# ..                                                 ...
# 995                                                nan
# 996                                                nan
# 997                                                nan
# 998                                                nan
# 999                                                nan
#
#                                               job_fac2  \
# 0    languages, frameworks, and other technologies ...
# 1                                                  nan
# 2                                                  nan
# 3        specific department or team i’d be working on
# 4    languages, frameworks, and other technologies ...
# ..                                                 ...
# 995                                                nan
# 996                                                nan
# 997                                                nan
# 998                                                nan
# 999                                                nan
#
#                                        job_fac3
# 0                           remote work options
# 1                                           nan
# 2                                           nan
# 3    opportunities for professional development
# 4                           remote work options
# ..                                          ...
# 995                                         nan
# 996                                         nan
# 997                                         nan
# 998                                         nan
# 999                                         nan
#
# [1000 rows x 60 columns]

# %%
map_dict = {'yes': 'True'}

# %%
survey_df['hobbyist'].replace(map_dict) # yes 会变成 True，其他保持不变
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4        no
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: hobbyist, Length: 1000, dtype: object

# %%
# https://numpy.org/doc/stable/reference/routines.math.html
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4       NaN
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: hobbyist, Length: 1000, dtype: object

# %%
# 找出所有以编程为兴趣，并且年龄小于25岁的用户。
# 在原来的dataframe中给这些特定用户新添一个column叫做code_years，这列的值等于user_age – age1stcode
